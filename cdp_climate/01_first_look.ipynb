# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from source.utility import list_all_files

pd.set_option('max_columns', 200)

# %% [markdown]
# # Cities responses

# %%
city_ddict = pd.read_csv('data/raw/Cities/Cities Responses/Full_Cities_Response_Data_Dictionary.csv')

city_ddict.head()
# Out:
#                   field                                        description  \
# 0         Questionnaire  Questionnaire and questionnaire year the compa...
# 1  Year Reported to CDP              Cities Disclosure cycle survey year.
# 2        Account Number  The unique identifier given to every city orga...
# 3          Organization           Name of the City organisation disclosing
# 4               Country                                    Country of city
#
#             column _entries example
# 0               Cities 2020     NaN
# 1                      2020     NaN
# 2                     35883     NaN
# 3          City of San Jose     NaN
# 4  United States of America     NaN

# %%
city_ddict
# Out:
#                    field                                        description  \
# 0          Questionnaire  Questionnaire and questionnaire year the compa...
# 1   Year Reported to CDP              Cities Disclosure cycle survey year.
# 2         Account Number  The unique identifier given to every city orga...
# 3           Organization           Name of the City organisation disclosing
# 4                Country                                    Country of city
# 5             CDP Region        CDP operation region City is located within
# 6         Parent Section  Module ('Parent Section') of the CDP questionn...
# 7                Section  Section of the CDP questionnaire the question ...
# 8        Question Number                        Question number of response
# 9          Question Name                                      Question name
# 10         Column Number  Column number of matrix set (Table) or matrix ...
# ...

# %%
city_2018 = pd.read_csv('data/raw/Cities/Cities Responses/2018_Full_Cities_Dataset.csv')

city_2018.head()
# Out:
#      Questionnaire  Year Reported to CDP  Account Number  \
# 0  CDP Cities 2018                  2018            3203
# 1  CDP Cities 2018                  2018           50555
# 2  CDP Cities 2018                  2018           50392
# 3  CDP Cities 2018                  2018           36522
# 4  CDP Cities 2018                  2018           35873
#
#                Organization                   Country     CDP Region  \
# 0           City of Chicago  United States of America  North America
# 1          City of Hamilton                    Canada  North America
# 2     Prefeitura de Vitória                    Brazil  Latin America
# 3        Comune di Verbania                     Italy         Europe
# 4  Municipality of Medellín                  Colombia  Latin America
#
#                    Parent Section                                  Section  \
# 0                           Water                               Wastewater
# ...

# %%
city_2019 = pd.read_csv('data/raw/Cities/Cities Responses/2019_Full_Cities_Dataset.csv')

city_2019.head()
# Out:
#   Questionnaire  Year Reported to CDP  Account Number       Organization  \
# 0   Cities 2019                  2019           54113  City of Flagstaff
# 1   Cities 2019                  2019           35894  Ville de Montreal
# 2   Cities 2019                  2019           44185         Suwon City
# 3   Cities 2019                  2019           59165   Gladsaxe Kommune
# 4   Cities 2019                  2019           36263  Comune di Ravenna
#
#                     Country     CDP Region       Parent Section  \
# 0  United States of America  North America                  NaN
# 1                    Canada  North America  Emissions Reduction
# 2         Republic of Korea      East Asia  Emissions Reduction
# 3                   Denmark         Europe                  NaN
# 4                     Italy         Europe       Water Security
#
#                      Section Question Number  \
# 0                     Energy            8.0a
# 1         Mitigation Actions             5.4
# ...

# %% [markdown]
# # Cities disclosing

# %%
list_all_files(location='data/', pattern='Cities Disclosing')
# Out:
# ['data/raw/Cities/Cities Disclosing/Cities_Disclosing_to_CDP_Data_Dictionary.csv',
#  'data/raw/Cities/Cities Disclosing/2018_Cities_Disclosing_to_CDP.csv',
#  'data/raw/Cities/Cities Disclosing/2019_Cities_Disclosing_to_CDP.csv',
#  'data/raw/Cities/Cities Disclosing/2020_Cities_Disclosing_to_CDP.csv']

# %%
cities_ddict = pd.read_csv('data/raw/Cities/Cities Disclosing/Cities_Disclosing_to_CDP_Data_Dictionary.csv')
cities_ddict.head()
# Out:
#                   field                                        description  \
# 0  Year Reported to CDP              Cities Disclosure cycle survey year.
# 1        Account Number  The unique identifier given to every city orga...
# 2          Organization           Name of the City organisation disclosing
# 3                  City  Name of the City the city organisation is disc...
# 4               Country                                    Country of city
#
#                                      column _entries example
# 0                                               2020     NaN
# 1                                              49335     NaN
# 2  Metropolitan Government of Nashville and David...     NaN
# 3                                          Nashville     NaN
# 4                           United States of America     NaN

# %%
cities_2018 = pd.read_csv('data/raw/Cities/Cities Disclosing/2018_Cities_Disclosing_to_CDP.csv')

cities_2018.head()
# Out:
#    Year Reported to CDP  Account Number  \
# 0                  2018           58671
# 1                  2018           59167
# 2                  2018           50553
# 3                  2018          826407
# 4                  2018           60375
#
#                                   Organization                        City  \
# 0    Helsingør Kommune / Elsinore Municipality                   Helsingør
# 1                 Municipalidad de Providencia                 Providencia
# 2                               City of Fresno                      Fresno
# 3                       Munícipio de Mirandela                   Mirandela
# 4  Gobiernación del Archipiélago de San Andrés  Archipiélago de San Andrés
#
#                     Country     CDP Region Reporting Authority  Access  \
# 0                   Denmark         Europe          CDP Cities  public
# 1                     Chile  Latin America          CDP Cities  public
# ...

# %% [markdown]
# # Corporations disclosing

# %%
list_all_files(location='data/', pattern='Corporations Disclosing')
# Out:
# ['data/raw/Corporations/Corporations Disclosing/Climate Change/Corporations_Disclosing_to_CDP_Data_Dictionary.csv',
#  'data/raw/Corporations/Corporations Disclosing/Climate Change/2018_Corporates_Disclosing_to_CDP_Climate_Change.csv',
#  'data/raw/Corporations/Corporations Disclosing/Climate Change/2019_Corporates_Disclosing_to_CDP_Climate_Change.csv',
#  'data/raw/Corporations/Corporations Disclosing/Climate Change/2020_Corporates_Disclosing_to_CDP_Climate_Change.csv',
#  'data/raw/Corporations/Corporations Disclosing/Water Security/2020_Corporates_Disclosing_to_CDP_Water_Security.csv',
#  'data/raw/Corporations/Corporations Disclosing/Water Security/2018_Corporates_Disclosing_to_CDP_Water_Security.csv',
#  'data/raw/Corporations/Corporations Disclosing/Water Security/Corporations_Disclosing_to_CDP_Data_Dictionary.csv',
#  'data/raw/Corporations/Corporations Disclosing/Water Security/2019_Corporates_Disclosing_to_CDP_Water_Security.csv']

# %%
corp_ddict = pd.read_csv('data/raw/Corporations/Corporations Disclosing/Climate Change/Corporations_Disclosing_to_CDP_Data_Dictionary.csv')

corp_ddict
# Out:
#                            field  \
# 0                 account_number
# 1                   organization
# 2                    survey_year
# 3                        country
# 4                         region
# 5              invitation_status
# 6                         public
# 7                        samples
# 8         response_received_date
# 9                   minimum_tier
# 10                 selected_tier
# 11                 questionnaire
# 12                         theme
# 13               authority_types
# 14                    activities
# 15                       sectors
# 16                    industries
# 17              primary_activity
# 18                primary_sector
# 19              primary_industry
# 20  primary_questionnaire_sector
# 21                primary_ticker
# 22                       tickers
#
#                                           description  \
# 0   The unique identifier given to every company t...
# ...

# %%
corp_cl_2018 = pd.read_csv('data/raw/Corporations/Corporations Disclosing/Climate Change/2018_Corporates_Disclosing_to_CDP_Climate_Change.csv')

corp_cl_2018.head()
# Out:
#    account_number                        organization  survey_year  \
# 0             912              Archer Daniels Midland         2018
# 1           14683                         Pfizer Inc.         2018
# 2            1708             Berry Global Group, Inc         2018
# 3           17166              SNC-Lavalin Group Inc.         2018
# 4            2670  Canadian Tire Corporation, Limited         2018
#
#                     country region invitation_status  public  \
# 0  United States of America    NaN         Submitted  public
# 1  United States of America    NaN         Submitted  public
# 2  United States of America    NaN         Submitted  public
# 3                    Canada    NaN         Submitted  public
# 4                    Canada    NaN         Submitted  public
#
#                                              samples response_received_date  \
# 0   Agriculture, Benchmark, CCGR1000, CCGR1800, E...   2018-09-04T00:00:00Z
# ...

# %%
corp_w_2018 = pd.read_csv('data/raw/Corporations/Corporations Disclosing/Water Security/2018_Corporates_Disclosing_to_CDP_Water_Security.csv')

corp_w_2018.head()
# Out:
#    account_number                             organization  survey_year  \
# 0           19582       Johnson Controls International PLC         2018
# 1            9336  International Flavors & Fragrances Inc.         2018
# 2           22901                            Bemis Company         2018
# 3            2407                                    Bunge         2018
# 4            3876                   Ingredion Incorporated         2018
#
#                     country region invitation_status  public  \
# 0  United States of America    NaN         Submitted  public
# 1  United States of America    NaN         Submitted  public
# 2  United States of America    NaN         Submitted  public
# 3  United States of America    NaN         Submitted  public
# 4  United States of America    NaN         Submitted  public
#
#                           samples response_received_date  minimum_tier  \
# 0                    Water Global   2018-08-29T00:00:00Z  Water - Full
# ...

# %%
corp_w_2018.country.value_counts()
# Out:
# United States of America    192
# Canada                       17
# Name: country, dtype: int64

# %% [markdown]
# # Corporations responses

# %%
list_all_files(location='data/', pattern='Corporations Responses')
# Out:
# ['data/raw/Corporations/Corporations Responses/Climate Change/2019_Full_Climate_Change_Dataset.csv',
#  'data/raw/Corporations/Corporations Responses/Climate Change/2018_Full_Climate_Change_Dataset.csv',
#  'data/raw/Corporations/Corporations Responses/Climate Change/2020_Full_Climate_Change_Dataset.csv',
#  'data/raw/Corporations/Corporations Responses/Climate Change/Full_Corporations_Response_Data_Dictionary copy.csv',
#  'data/raw/Corporations/Corporations Responses/Water Security/2020_Full_Water_Security_Dataset.csv',
#  'data/raw/Corporations/Corporations Responses/Water Security/2019_Full_Water_Security_Dataset.csv',
#  'data/raw/Corporations/Corporations Responses/Water Security/2018_Full_Water_Security_Dataset.csv',
#  'data/raw/Corporations/Corporations Responses/Water Security/Full_Corporations_Response_Data_Dictionary.csv']

# %%
corp_cl_2018 = pd.read_csv('data/raw/Corporations/Corporations Responses/Climate Change/2018_Full_Climate_Change_Dataset.csv')

corp_cl_2018.head()
# Out:
#    account_number            organization  survey_year response_received_date  \
# 0             912  Archer Daniels Midland         2018   2018-09-04T00:00:00Z
# 1             912  Archer Daniels Midland         2018   2018-09-04T00:00:00Z
# 2             912  Archer Daniels Midland         2018   2018-09-04T00:00:00Z
# 3             912  Archer Daniels Midland         2018   2018-09-04T00:00:00Z
# 4             912  Archer Daniels Midland         2018   2018-09-04T00:00:00Z
#
#   accounting_period_to  ors_response_id       submission_date page_name  \
# 0                  NaN            13370  2018-10-24T16:36:50Z      C0.2
# 1                  NaN            13370  2018-10-24T16:36:50Z      C0.4
# 2                  NaN            13370  2018-10-24T16:36:50Z      C0.2
# 3                  NaN            13370  2018-10-24T16:36:50Z      C0.3
# 4                  NaN            13370  2018-10-24T16:36:50Z      C0.5
#
#         module_name question_number  \
# ...
