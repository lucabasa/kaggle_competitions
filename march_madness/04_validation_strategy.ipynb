# %%
import pandas as pd
import numpy as np

import source.utility as ut
import source.transf_univ as df_p
import source.report as rp

from sklearn.model_selection import KFold

from sklearn.linear_model import Ridge, LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, mean_squared_error, mean_absolute_error, log_loss

from scipy.interpolate import UnivariateSpline

import matplotlib.pyplot as plt
# %matplotlib inline

pd.set_option('max_columns', 300)

# %%
df = pd.read_csv('data/processed_men/training_data.csv')

df.head()
# Out:
#    Season  DayNum  Team1  Team2  target  target_points  T1_Loc  T2_Loc  \
# 0    2003     134   1411   1421       0             -8       0       0
# 1    2003     136   1112   1436       1             29       0       0
# 2    2003     136   1113   1272       1             13       0       0
# 3    2003     136   1141   1166       1              6       0       0
# 4    2003     136   1143   1301       1              2       0       0
#
#                ID   T1_Score     T1_FGM     T1_FGA   T1_FGM3    T1_FGA3  \
# 0  2003_1411_1421  72.800000  24.733333  55.266667  5.933333  18.500000
# 1  2003_1112_1436  85.214286  30.321429  65.714286  7.035714  20.071429
# 2  2003_1113_1272  75.965517  27.206897  56.896552  4.000000  12.586207
# 3  2003_1141_1166  79.344828  26.620690  52.689655  6.827586  17.931034
# 4  2003_1143_1301  74.482759  27.344828  58.724138  6.413793  17.034483
#
#       T1_FTM     T1_FTA      T1_OR      T1_DR     T1_Ast      T1_TO    T1_Stl  \
# 0  17.400000  28.066667  13.166667  24.800000  14.200000  15.233333  6.433333
# 1  17.535714  25.000000  15.178571  27.642857  17.642857  14.785714  8.464286
# 2  17.551724  26.206897  13.689655  23.310345  15.551724  14.000000  5.206897
# 3  19.275862  25.172414  10.586207  23.275862  15.620690  18.241379  7.103448
# 4  13.379310  19.517241  11.241379  24.379310  16.000000  14.172414  6.551724
#
#      T1_Blk      T1_PF    T1_FGM2    T1_FGA2  T1_Tot_Reb  T1_FGM_no_ast  \
# 0  2.233333  18.300000  18.800000  36.766667   37.966667      10.533333
# 1  4.214286  17.750000  23.285714  45.642857   42.821429      12.678571
# 2  4.241379  19.413793  23.206897  44.310345   37.000000      11.655172
# 3  4.000000  20.965517  19.793103  34.758621   33.862069      11.000000
# 4  2.793103  17.103448  20.931034  41.689655   35.620690      11.344828
#
#    T1_possessions  T1_off_rating  T1_scoring_opp  T1_TO_perposs  \
# 0       44.001667     173.193342        1.634307       0.361196
# 1       53.446429     163.190982        1.480171       0.277429
# 2       44.758621     194.483479        1.779885       0.351562
# 3       48.387931     168.134256        1.368839       0.380177
# 4       52.384483     146.432959        1.329476       0.273503
#
#    T1_def_rating  T1_impact  T1_Def_effort  T1_Reb_opp  T1_Score_diff  \
# 0     134.807976   0.532616      89.351498    0.724640       1.966667
# 1     120.051621   0.610487      89.662065    0.724040      14.964286
# 2     139.972635   0.555831      79.641868    0.764390       6.793103
# 3     147.637906   0.563786      78.383866    0.752266       6.103448
# 4     133.745572   0.540047      83.945207    0.736381       4.724138
#
#    T1_FGM_diff  T1_FGA_diff  T1_FGM3_diff  T1_FGA3_diff  T1_FTM_diff  \
# 0    -0.933333    -5.133333     -1.600000     -4.666667     5.433333
# 1     3.964286     1.035714      0.714286      0.107143     6.321429
# 2     2.413793     1.241379     -1.448276     -3.310345     3.413793
# 3     0.275862    -5.241379      1.862069      4.034483     3.689655
# 4     1.965517    -0.068966     -0.689655     -4.413793     1.482759
#
#    T1_FTA_diff  T1_OR_diff  T1_DR_diff  T1_Ast_diff  T1_TO_diff  T1_Stl_diff  \
# 0     9.333333    1.233333    1.933333     0.433333    0.900000    -1.566667
# 1     7.285714    2.071429    4.357143     2.178571   -2.071429     2.500000
# 2     5.689655    2.689655    2.758621     1.482759   -1.517241    -0.793103
# 3     3.206897   -1.655172    4.379310     3.827586    2.172414    -1.344828
# 4     2.068966    0.068966    1.379310    -0.034483   -0.758621     0.620690
#
#    T1_Blk_diff  T1_PF_diff  T1_FGM2_diff  T1_FGA2_diff  T1_Tot_Reb_diff  \
# 0    -0.366667   -3.333333      0.666667     -0.466667         3.166667
# 1     1.821429   -4.321429      3.250000      0.928571         6.428571
# 2     0.310345   -3.448276      3.862069      4.551724         5.448276
# 3     1.517241   -0.724138     -1.586207     -9.275862         2.724138
# 4     0.275862   -2.000000      2.655172      4.344828         1.448276
#
#    T1_FGM_no_ast_diff  T1_Def_effort_diff  T1_Reb_opp_diff  \
# 0           -1.366667           -1.606612        -0.033819
# 1            1.785714            0.679357         0.060072
# 2            0.931034            1.481430         0.064969
# 3           -3.551724            0.234549         0.023430
# 4            2.000000            5.021823        -0.006878
#
#    T1_possessions_diff  T1_off_rating_diff  T1_def_rating_diff  \
# 0            -9.900000           38.385366          -38.385366
# 1            -6.567857           43.139360          -43.139360
# 2            -5.668103           54.510845          -54.510845
# 3            -2.937069           20.496350          -20.496350
# 4            -1.879310           12.687387          -12.687387
#
#    T1_scoring_opp_diff  T1_TO_perposs_diff  T1_impact_diff  T1_N_wins  \
# 0             0.321635            0.091486        0.065232   0.600000
# 1             0.231833           -0.003647        0.220973   0.892857
# 2             0.463875            0.039623        0.111663   0.620690
# 3            -0.003194            0.064073        0.127571   0.793103
# 4             0.055891           -0.001014        0.080094   0.724138
#
#    T1_FGM_perc  T1_FGM2_perc  T1_FGM3_perc  T1_FT_perc  T1_FGM_no_ast_perc  \
# 0     0.447527      0.511333      0.320721    0.619952            0.425876
# 1     0.461413      0.510172      0.350534    0.701429            0.418139
# 2     0.478182      0.523735      0.317808    0.669737            0.428390
# 3     0.505236      0.569444      0.380769    0.765753            0.413212
# 4     0.465649      0.502068      0.376518    0.685512            0.414880
#
#    T1_L2W_Score  T1_L2W_FGM  T1_L2W_FGA  T1_L2W_FGM3  T1_L2W_FGA3  T1_L2W_FTM  \
# 0     73.333333   24.666667   50.333333          4.5    13.833333   19.500000
# 1     83.000000   30.333333   73.333333          6.0    23.333333   16.333333
# 2     79.750000   29.250000   59.750000          4.0    11.750000   17.250000
# 3     83.400000   25.400000   49.200000          8.2    17.800000   24.400000
# 4     67.750000   24.750000   58.750000          6.5    17.000000   11.750000
#
#    T1_L2W_FTA  T1_L2W_OR  T1_L2W_DR  T1_L2W_Ast  T1_L2W_TO  T1_L2W_Stl  \
# 0   32.000000  12.333333  25.166667   15.166667  16.000000        5.50
# 1   23.333333  16.000000  25.666667   18.333333  11.666667       11.00
# 2   24.250000  13.000000  23.000000   16.500000  13.250000        5.00
# 3   30.600000  11.400000  25.000000   16.000000  16.800000        7.80
# 4   17.250000  13.500000  25.000000   13.000000  13.250000        4.25
#
#    T1_L2W_Blk  T1_L2W_PF  T1_L2W_FGM2  T1_L2W_FGA2  T1_L2W_Tot_Reb  \
# 0    3.666667  18.166667    20.166667        36.50       37.500000
# 1    4.000000  18.666667    24.333333        50.00       41.666667
# 2    2.750000  19.250000    25.250000        48.00       36.000000
# 3    4.400000  17.000000    17.200000        31.40       36.400000
# 4    3.500000  17.500000    18.250000        41.75       38.500000
#
#    T1_L2W_FGM_no_ast  T1_L2W_possessions  T1_L2W_off_rating  \
# 0               9.50           38.800000         191.877886
# 1              12.00           57.916667         150.284112
# 2              12.75           48.481250         166.774557
# 3               9.40           40.065000         211.283416
# 4              11.75           50.306250         138.126908
#
#    T1_L2W_scoring_opp  T1_L2W_TO_perposs  T1_L2W_def_rating  T1_L2W_impact  \
# 0            1.721900           0.417083         134.045433       0.573010
# 1            1.507152           0.204945         144.037684       0.541402
# 2            1.482850           0.269633         156.036238       0.525978
# 3            1.603130           0.422875         122.356393       0.668093
# 4            1.345947           0.261661         140.272318       0.522393
#
#    T1_L2W_Def_effort  T1_L2W_Reb_opp  T1_L2W_Score_diff  T1_L2W_FGM_diff  \
# 0          91.079257        0.705800           5.333333         0.333333
# 1          95.082459        0.733162           4.333333         3.666667
# 2          80.725170        0.795550           3.750000         3.250000
# 3          75.408002        0.697392          17.000000         1.000000
# 4          85.521311        0.657027           0.500000         0.250000
#
#    T1_L2W_FGA_diff  T1_L2W_FGM3_diff  T1_L2W_FGA3_diff  T1_L2W_FTM_diff  \
# 0       -10.500000         -1.666667         -6.166667         6.333333
# 1        11.666667         -0.333333          6.333333        -2.666667
# 2         4.250000         -2.500000         -4.000000        -0.250000
# 3       -11.400000          2.200000          2.000000        12.800000
# 4        -3.750000          0.250000         -3.000000        -0.250000
#
#    T1_L2W_FTA_diff  T1_L2W_OR_diff  T1_L2W_DR_diff  T1_L2W_Ast_diff  \
# 0            12.50        0.333333        4.833333         1.333333
# 1            -3.00        4.333333       -3.333333         5.000000
# 2             1.75        3.750000        4.250000         0.500000
# 3            14.60       -2.600000        8.800000         6.200000
# 4            -0.75       -1.000000        2.000000        -1.000000
#
#    T1_L2W_TO_diff  T1_L2W_Stl_diff  T1_L2W_Blk_diff  T1_L2W_PF_diff  \
# 0        2.833333        -2.833333         1.166667       -4.166667
# 1       -5.333333         5.333333         1.666667       -2.000000
# 2       -0.750000        -0.750000         0.000000       -2.000000
# 3        1.200000        -2.200000         2.200000       -6.200000
# 4        3.000000        -2.500000         1.000000       -0.500000
#
#    T1_L2W_FGM2_diff  T1_L2W_FGA2_diff  T1_L2W_Tot_Reb_diff  \
# 0              2.00         -4.333333             5.166667
# 1              4.00          5.333333             1.000000
# 2              5.75          8.250000             8.000000
# 3             -1.20        -13.400000             6.200000
# 4              0.00         -0.750000             1.000000
#
#    T1_L2W_FGM_no_ast_diff  T1_L2W_Def_effort_diff  T1_L2W_Reb_opp_diff  \
# 0               -1.000000                5.493487            -0.089343
# 1               -1.333333               -8.311481             0.043727
# 2                2.750000                4.526985             0.166115
# 3               -5.200000               -2.924655             0.012346
# 4                1.250000                9.822361            -0.019278
#
#    T1_L2W_possessions_diff  T1_L2W_off_rating_diff  T1_L2W_def_rating_diff  \
# 0                -13.93750               57.832452              -57.832452
# 1                  3.42500                6.246427               -6.246427
# 2                 -1.08125               10.738319              -10.738319
# 3                -14.53500               88.927023              -88.927023
# 4                  0.60625               -2.145410                2.145410
#
#    T1_L2W_scoring_opp_diff  T1_L2W_TO_perposs_diff  T1_L2W_impact_diff  \
# 0                 0.353729                0.157792            0.146019
# 1                 0.143801               -0.111217            0.082804
# 2                 0.134021               -0.009214            0.051955
# 3                 0.348253                0.133739            0.336185
# 4                -0.112400                0.055724            0.044786
#
#    T1_L2W_N_wins  T1_L2W_FGM_perc  T1_L2W_FGM2_perc  T1_L2W_FGM3_perc  \
# 0       0.833333         0.490066          0.552511          0.325301
# 1       0.666667         0.413636          0.486667          0.257143
# 2       0.500000         0.489540          0.526042          0.340426
# 3       1.000000         0.516260          0.547771          0.460674
# 4       0.500000         0.421277          0.437126          0.382353
#
#    T1_L2W_FT_perc  T1_L2W_FGM_no_ast_perc  T1_Seed   T2_Score     T2_FGM  \
# 0        0.609375                0.385135     16.0  71.206897  24.379310
# 1        0.700000                0.395604      1.0  67.793103  24.827586
# 2        0.711340                0.435897     10.0  74.517241  26.275862
# 3        0.797386                0.370079     11.0  79.242424  28.696970
# 4        0.681159                0.474747      8.0  72.400000  24.333333
#
#       T2_FGA   T2_FGM3    T2_FGA3     T2_FTM     T2_FTA      T2_OR      T2_DR  \
# 0  56.793103  6.482759  18.000000  15.965517  20.931034  12.275862  23.172414
# 1  55.862069  5.275862  15.482759  12.862069  19.551724  12.965517  25.724138
# 2  60.000000  7.000000  20.068966  14.965517  22.896552  14.068966  25.965517
# 3  57.454545  7.969697  20.484848  13.878788  20.030303  10.878788  23.181818
# 4  53.333333  7.966667  22.500000  15.766667  20.466667   9.733333  22.033333
#
#       T2_Ast      T2_TO    T2_Stl    T2_Blk      T2_PF    T2_FGM2    T2_FGA2  \
# 0  13.034483  16.206897  7.068966  3.000000  19.103448  17.896552  38.793103
# 1  14.206897  14.068966  6.862069  2.965517  15.896552  19.551724  40.379310
# 2  16.620690  13.793103  7.379310  5.068966  18.758621  19.275862  39.931034
# 3  16.818182  13.363636  8.393939  4.454545  17.272727  20.727273  36.969697
# 4  14.666667  14.200000  7.766667  3.066667  18.666667  16.366667  30.833333
#
#    T2_Tot_Reb  T2_FGM_no_ast  T2_possessions  T2_off_rating  T2_scoring_opp  \
# 0   35.448276      11.344828       50.781897     146.966608        1.366193
# 1   38.689655      10.620690       47.678448     145.085351        1.390562
# 2   40.034483       9.655172       48.848276     160.534517        1.534799
# 3   34.060606      11.878788       50.425000     159.201185        1.352442
# 4   31.766667       9.666667       48.078333     153.248750        1.329383
#
#    T2_TO_perposs  T2_def_rating  T2_impact  ...  T2_L2W_FGM_diff  \
# 0       0.318689     163.179577   0.466801  ...         3.333333
# 1       0.298521     126.379086   0.551970  ...         5.500000
# 2       0.294052     136.397001   0.569044  ...         1.000000
# 3       0.267607     122.706608   0.596778  ...         4.250000
# 4       0.295583     150.439920   0.530770  ...        -1.666667
#
#    T2_L2W_FGA_diff  T2_L2W_FGM3_diff  T2_L2W_FGA3_diff  T2_L2W_FTM_diff  \
# 0            -3.00         -2.000000         -6.666667         1.000000
# 1             0.25         -3.000000         -7.250000         3.250000
# 2            -1.25          4.250000          5.500000         1.000000
# 3            -1.25          1.750000          1.750000         2.750000
# 4            -6.50          3.166667          5.500000        -0.333333
#
#    T2_L2W_FTA_diff  T2_L2W_OR_diff  T2_L2W_DR_diff  T2_L2W_Ast_diff  \
# 0            -2.00       -1.666667            7.00        -0.333333
# 1             5.25        3.750000            7.25         5.500000
# 2            -2.50       -1.750000            2.25         5.250000
# 3             4.50       -0.750000            4.00         3.750000
# 4            -1.50       -2.500000            2.50         1.166667
#
#    T2_L2W_TO_diff  T2_L2W_Stl_diff  T2_L2W_Blk_diff  T2_L2W_PF_diff  \
# 0            2.00        -0.666667        -1.666667            0.00
# 1            0.75         0.250000        -0.250000           -2.25
# 2            0.75        -3.250000         2.750000            2.25
# 3           -2.50         0.750000         3.250000           -0.25
# 4            5.00        -3.833333         0.666667           -1.50
#
#    T2_L2W_FGM2_diff  T2_L2W_FGA2_diff  T2_L2W_Tot_Reb_diff  \
# 0          5.333333          3.666667             5.333333
# 1          8.500000          7.500000            11.000000
# 2         -3.250000         -6.750000             0.500000
# 3          2.500000         -3.000000             3.250000
# 4         -4.833333        -12.000000             0.000000
#
#    T2_L2W_FGM_no_ast_diff  T2_L2W_Def_effort_diff  T2_L2W_Reb_opp_diff  \
# 0                3.666667               19.788824             0.066979
# 1                0.000000               15.300060             0.129008
# 2               -4.250000                4.507370            -0.004405
# 3                0.500000                1.607537             0.017284
# 4               -2.833333                3.798480            -0.034500
#
#    T2_L2W_possessions_diff  T2_L2W_off_rating_diff  T2_L2W_def_rating_diff  \
# 0                 1.616667               11.415192              -11.415192
# 1                -5.243750               37.721873              -37.721873
# 2                 2.437500                3.868618               -3.868618
# 3                -5.137500               38.270550              -38.270550
# 4                 1.712500              -10.472643               10.472643
#
#    T2_L2W_scoring_opp_diff  T2_L2W_TO_perposs_diff  T2_L2W_impact_diff  \
# 0                -0.082104                0.027475            0.128742
# 1                 0.190963                0.053941            0.269388
# 2                -0.167111                0.007417            0.111734
# 3                 0.171306               -0.018821            0.204465
# 4                -0.248411                0.103641            0.050771
#
#    T2_L2W_N_wins  T2_L2W_FGM_perc  T2_L2W_FGM2_perc  T2_L2W_FGM3_perc  \
# 0           1.00         0.464481          0.496124          0.388889
# 1           1.00         0.488263          0.544872          0.333333
# 2           0.75         0.441441          0.477612          0.386364
# 3           1.00         0.466960          0.512346          0.353846
# 4           0.50         0.465574          0.502762          0.411290
#
#    T2_L2W_FT_perc  T2_L2W_FGM_no_ast_perc  T2_Seed  delta_Loc  delta_Score  \
# 0        0.767857                0.505882     16.0          0     1.593103
# 1        0.605263                0.365385     16.0          0    17.421182
# 2        0.666667                0.346939      7.0          0     1.448276
# 3        0.716049                0.415094      6.0          0     0.102403
# 4        0.781250                0.408451      9.0          0     2.082759
#
#    delta_FGM  delta_FGA  delta_FGM3  delta_FGA3  delta_FTM  delta_FTA  \
# 0   0.354023  -1.526437   -0.549425    0.500000   1.434483   7.135632
# 1   5.493842   9.852217    1.759852    4.588670   4.673645   5.448276
# 2   0.931034  -3.103448   -3.000000   -7.482759   2.586207   3.310345
# 3  -2.076280  -4.764890   -1.142111   -2.553814   5.397074   5.142111
# 4   3.011494   5.390805   -1.552874   -5.465517  -2.387356  -0.949425
#
#    delta_OR  delta_DR  delta_Ast  delta_TO  delta_Stl  delta_Blk  delta_PF  \
# 0  0.890805  1.627586   1.165517 -0.973563  -0.635632  -0.766667 -0.803448
# 1  2.213054  1.918719   3.435961  0.716749   1.602217   1.248768  1.853448
# 2 -0.379310 -2.655172  -1.068966  0.206897  -2.172414  -0.827586  0.655172
# 3 -0.292581  0.094044  -1.197492  4.877743  -1.290491  -0.454545  3.692790
# 4  1.508046  2.345977   1.333333 -0.027586  -1.214943  -0.273563 -1.563218
#
#    delta_FGM2  delta_FGA2  delta_Tot_Reb  delta_FGM_no_ast  delta_possessions  \
# 0    0.903448   -2.026437       2.518391         -0.811494          -6.780230
# 1    3.733990    5.263547       4.131773          2.057882           5.767980
# 2    3.931034    4.379310      -3.034483          2.000000          -4.089655
# 3   -0.934169   -2.211076      -0.198537         -0.878788          -2.037069
# 4    4.564368   10.856322       3.854023          1.678161           4.306149
#
#    delta_off_rating  delta_scoring_opp  delta_TO_perposs  delta_def_rating  \
# 0         26.226735           0.268114          0.042507        -28.371601
# 1         18.105630           0.089609         -0.021092         -6.327465
# 2         33.948963           0.245086          0.057510          3.575634
# 3          8.933071           0.016396          0.112570         24.931297
# 4         -6.815791           0.000093         -0.022080        -16.694348
#
#    delta_impact  delta_Def_effort  delta_Reb_opp  delta_Score_diff  \
# 0      0.065815          4.447735       0.026911          9.208046
# 1      0.058517          6.559291      -0.078613         10.309113
# 2     -0.013212         -8.166052      -0.000790         -1.896552
# 3     -0.032993          5.040954       0.007293         -8.805643
# 4      0.009277          3.775846      -0.019082          0.324138
#
#    delta_FGM_diff  delta_FGA_diff  delta_FGM3_diff  delta_FGA3_diff  \
# 0        2.480460       -0.960920        -0.462069        -1.908046
# 1        1.895320        0.242611         2.507389         6.072660
# 2       -0.586207       -0.896552        -2.551724        -5.068966
# 3       -4.542320       -7.362591        -1.228840        -2.147335
# 4        1.065517       -0.268966        -2.922989        -9.913793
#
#    delta_FTM_diff  delta_FTA_diff  delta_OR_diff  delta_DR_diff  \
# 0        4.709195       10.954023       2.681609       1.588506
# 1        4.011084        3.492611      -1.307882       0.495074
# 2        1.827586        3.517241       0.965517       0.379310
# 3        1.507837       -0.126437      -1.473354       2.561129
# 4        1.116092        2.802299       0.868966       0.779310
#
#    delta_Ast_diff  delta_TO_diff  delta_Stl_diff  delta_Blk_diff  \
# 0        3.260920      -2.479310        0.191954        0.874713
# 1        1.247537      -3.140394        2.741379        2.511084
# 2       -1.827586      -0.241379       -0.896552       -1.586207
# 3       -0.626959       5.869383       -3.405434       -0.361546
# 4       -2.134483      -0.325287        0.287356        0.042529
#
#    delta_PF_diff  delta_FGM2_diff  delta_FGA2_diff  delta_Tot_Reb_diff  \
# 0      -3.747126         2.942529         0.947126            4.270115
# 1      -2.286946        -0.612069        -5.830049           -0.812808
# 2      -2.275862         1.965517         4.172414            1.344828
# 3       1.397074        -3.313480        -5.215256            1.087774
# 4      -1.333333         3.988506         9.644828            1.648276
#
#    delta_FGM_no_ast_diff  delta_Def_effort_diff  delta_Reb_opp_diff  \
# 0              -0.780460              -6.052105           -0.021168
# 1               0.647783              -8.076209           -0.043506
# 2               1.241379              -0.118554            0.011851
# 3              -3.915361               4.636493            0.024945
# 4               3.200000               7.543889           -0.017203
#
#    delta_possessions_diff  delta_off_rating_diff  delta_def_rating_diff  \
# 0              -11.325000              54.598336             -54.598336
# 1               -3.248892              24.433096             -24.433096
# 2               -3.774138              30.373329             -30.373329
# 3                0.040204             -15.998227              15.998227
# 4               -2.794310               9.878557              -9.878557
#
#    delta_scoring_opp_diff  delta_TO_perposs_diff  delta_impact_diff  \
# 0                0.453872               0.036971           0.131630
# 1                0.093510              -0.047658           0.117033
# 2                0.318198               0.045053          -0.026424
# 3               -0.149038               0.115188          -0.065986
# 4                0.111462               0.015953           0.018553
#
#    delta_N_wins  delta_FGM_perc  delta_FGM2_perc  delta_FGM3_perc  \
# 0      0.151724        0.018262         0.049999        -0.039433
# 1      0.237685        0.016969         0.025971         0.009777
# 2     -0.172414        0.040251         0.041007        -0.030989
# 3     -0.085684        0.005763         0.008789        -0.008284
# 4      0.124138        0.009399        -0.028743         0.022444
#
#    delta_FT_perc  delta_FGM_no_ast_perc  delta_L2W_Score  delta_L2W_FGM  \
# 0      -0.142815              -0.039471        -4.666667      -3.666667
# 1       0.043580              -0.009639        14.750000       4.333333
# 2       0.016122               0.060936         5.250000       4.750000
# 3       0.072864              -0.000726        10.150000      -1.100000
# 4      -0.084846               0.017620        -4.750000       1.083333
#
#    delta_L2W_FGA  delta_L2W_FGM3  delta_L2W_FGA3  delta_L2W_FTM  \
# 0     -10.666667           -2.50       -4.166667       5.166667
# 1      20.083333            1.25        9.083333       4.833333
# 2       4.250000           -4.50      -10.250000       0.250000
# 3      -7.550000            2.45        1.550000       9.900000
# 4       7.916667           -2.00       -3.666667      -4.916667
#
#    delta_L2W_FTA  delta_L2W_OR  delta_L2W_DR  delta_L2W_Ast  delta_L2W_TO  \
# 0      13.333333     -1.000000     -3.833333       1.166667     -0.333333
# 1       4.333333      4.500000     -1.083333       1.833333     -0.833333
# 2      -1.250000      0.500000     -2.500000       0.500000      1.000000
# 3      10.350000     -0.600000     -1.000000       0.500000      3.300000
# 4      -4.083333      4.166667      1.666667      -1.000000     -0.750000
#
#    delta_L2W_Stl  delta_L2W_Blk  delta_L2W_PF  delta_L2W_FGM2  delta_L2W_FGA2  \
# 0      -2.500000      -0.333333      0.500000       -1.166667       -6.500000
# 1       4.750000       1.750000      4.166667        3.083333       11.000000
# 2       0.250000      -2.000000     -3.000000        9.250000       14.500000
# 3       0.300000      -1.350000     -1.000000       -3.550000       -9.100000
# 4       0.583333       0.000000     -1.666667        3.083333       11.583333
#
#    delta_L2W_Tot_Reb  delta_L2W_FGM_no_ast  delta_L2W_possessions  \
# 0          -4.833333             -4.833333             -16.333333
# 1           3.416667              2.500000              12.691667
# 2          -2.000000              4.250000               5.343750
# 3          -1.600000             -1.600000              -8.566250
# 4           5.833333              2.083333               4.939583
#
#    delta_L2W_off_rating  delta_L2W_scoring_opp  delta_L2W_TO_perposs  \
# 0             43.345673               0.404546              0.119319
# 1             -2.254444               0.118337             -0.081978
# 2            -14.883776              -0.185838             -0.035125
# 3             60.576798               0.213583              0.142067
# 4            -23.603319              -0.006274             -0.048653
#
#    delta_L2W_def_rating  delta_L2W_impact  delta_L2W_Def_effort  \
# 0             -3.071587          0.008639             -3.022492
# 1             29.221002         -0.093292             10.220088
# 2            -21.753477         -0.029889            -13.572396
# 3              9.920325          0.065860             -1.723311
# 4            -31.930552         -0.002993              3.170956
#
#    delta_L2W_Reb_opp  delta_L2W_Score_diff  delta_L2W_FGM_diff  \
# 0          -0.035485             -0.333333           -3.000000
# 1          -0.103977             -6.916667           -1.833333
# 2           0.019172             -3.500000            2.250000
# 3          -0.046706              4.000000           -3.250000
# 4          -0.077792              1.000000            1.916667
#
#    delta_L2W_FGA_diff  delta_L2W_FGM3_diff  delta_L2W_FGA3_diff  \
# 0           -7.500000             0.333333             0.500000
# 1           11.416667             2.666667            13.583333
# 2            5.500000            -6.750000            -9.500000
# 3          -10.150000             0.450000             0.250000
# 4            2.750000            -2.916667            -8.500000
#
#    delta_L2W_FTM_diff  delta_L2W_FTA_diff  delta_L2W_OR_diff  \
# 0            5.333333               14.50           2.000000
# 1           -5.916667               -8.25           0.583333
# 2           -1.250000                4.25           5.500000
# 3           10.050000               10.10          -1.850000
# 4            0.083333                0.75           1.500000
#
#    delta_L2W_DR_diff  delta_L2W_Ast_diff  delta_L2W_TO_diff  \
# 0          -2.166667            1.666667           0.833333
# 1         -10.583333           -0.500000          -6.083333
# 2           2.000000           -4.750000          -1.500000
# 3           4.800000            2.450000           3.700000
# 4          -0.500000           -2.166667          -2.000000
#
#    delta_L2W_Stl_diff  delta_L2W_Blk_diff  delta_L2W_PF_diff  \
# 0           -2.166667            2.833333          -4.166667
# 1            5.083333            1.916667           0.250000
# 2            2.500000           -2.750000          -4.250000
# 3           -2.950000           -1.050000          -5.950000
# 4            1.333333            0.333333           1.000000
#
#    delta_L2W_FGM2_diff  delta_L2W_FGA2_diff  delta_L2W_Tot_Reb_diff  \
# 0            -3.333333            -8.000000               -0.166667
# 1            -4.500000            -2.166667              -10.000000
# 2             9.000000            15.000000                7.500000
# 3            -3.700000           -10.400000                2.950000
# 4             4.833333            11.250000                1.000000
#
#    delta_L2W_FGM_no_ast_diff  delta_L2W_Def_effort_diff  \
# 0                  -4.666667                 -14.295337
# 1                  -1.333333                 -23.611541
# 2                   7.000000                   0.019615
# 3                  -5.700000                  -4.532192
# 4                   4.083333                   6.023880
#
#    delta_L2W_Reb_opp_diff  delta_L2W_possessions_diff  \
# 0               -0.156322                  -15.554167
# 1               -0.085281                    8.668750
# 2                0.170521                   -3.518750
# 3               -0.004938                   -9.397500
# 4                0.015221                   -1.106250
#
#    delta_L2W_off_rating_diff  delta_L2W_def_rating_diff  \
# 0                  46.417261                 -46.417261
# 1                 -31.475446                  31.475446
# 2                   6.869701                  -6.869701
# 3                  50.656473                 -50.656473
# 4                   8.327233                  -8.327233
#
#    delta_L2W_scoring_opp_diff  delta_L2W_TO_perposs_diff  \
# 0                    0.435833                   0.130316
# 1                   -0.047162                  -0.165158
# 2                    0.301132                  -0.016631
# 3                    0.176947                   0.152559
# 4                    0.136011                  -0.047917
#
#    delta_L2W_impact_diff  delta_L2W_N_wins  delta_L2W_FGM_perc  \
# 0               0.017278         -0.166667            0.025585
# 1              -0.186584         -0.333333           -0.074627
# 2              -0.059778         -0.250000            0.048098
# 3               0.131721          0.000000            0.049300
# 4              -0.005986          0.000000           -0.044297
#
#    delta_L2W_FGM2_perc  delta_L2W_FGM3_perc  delta_L2W_FT_perc  \
# 0             0.056387            -0.063588          -0.158482
# 1            -0.058205            -0.076190           0.094737
# 2             0.048430            -0.045938           0.044674
# 3             0.035425             0.106828           0.081336
# 4            -0.065637            -0.028937          -0.100091
#
#    delta_L2W_FGM_no_ast_perc  delta_Seed
# 0                  -0.120747         0.0
# 1                   0.030220       -15.0
# 2                   0.088959         3.0
# 3                  -0.045016         5.0
# 4                   0.066297        -1.0
#
# [5 rows x 361 columns]

# %% [markdown]
# * Both on target and target_points
# * General 80/20 split, Kfold and test results
# * kfold on n-1 season and test on the remaining one

# %%
def _clean_columns(train, test):
    for col in ['target', 'target_points', 'ID', 'DayNum', 'Team1', 'Team2', 'Season']:
        try:
            del train[col]
            del test[col]
        except KeyError:
            pass
    return train, test


def _make_preds(train, y_train, test, model, kfolds, predict_proba):
    oof, imp_coef = ut.cv_score(train, y_train, kfolds, model, imp_coef=True, predict_proba=predict_proba)
    
    fit_model = model.fit(train, y_train)
    if predict_proba:
        predictions = fit_model.predict_proba(test)[:,1]
    else:
        predictions = fit_model.predict(test)
    
    return fit_model, oof, imp_coef, predictions


def random_split(data, model, kfolds, target, test_size=0.2, predict_proba=False):
    
    train, test = ut.make_test(data, test_size=test_size, random_state=324)
    
    y_train = train[target]
    y_test = test[target]
    
    train, test = _clean_columns(train, test)
    
    fit_model, oof, imp_coef, predictions = _make_preds(train, y_train, test, model, kfolds, predict_proba)
    
    return fit_model, oof, predictions, imp_coef, train, y_train, test, y_test

# %%
df_train = df[['Season', 'target', 'target_points', 'ID', 'delta_Seed', 'delta_Score']]

df_train.head()
# Out:
#    Season  target  target_points              ID  delta_Seed  delta_Score
# 0    2003       0             -8  2003_1411_1421         0.0     1.593103
# 1    2003       1             29  2003_1112_1436       -15.0    17.421182
# 2    2003       1             13  2003_1113_1272         3.0     1.448276
# 3    2003       1              6  2003_1141_1166         5.0     0.102403
# 4    2003       1              2  2003_1143_1301        -1.0     2.082759

# %%
pipe = Pipeline([('scl', df_p.df_scaler()), ('ridge', Ridge())])

kfolds = KFold(n_splits=5, shuffle=True, random_state=345)

fitted, oof_pred, test_pred, imp_coef, train, y_train, test, y_test = random_split(df_train, pipe, kfolds, 'target_points')

# %%
imp_coef
# Out:
#                  mean       std
# feat
# delta_Seed  -8.166931  0.217413
# delta_Score  0.687557  0.104488

# %%
def _point_to_proba(oof, y_train, preds):
    dat = list(zip(np.clip(oof, -30, 30), np.where(y_train > 0, 1, 0)))
    dat = sorted(dat, key = lambda x: x[0])
    datdict = {dat[k][0]: dat[k][1] for k in range(len(dat))}

    spline_model = UnivariateSpline(list(datdict.keys()), list(datdict.values()))  
    spline_oof = spline_model(oof)
    spline_test = spline_model(preds)
    
    return spline_oof, spline_test


def _plot_proba(score, label, spline, ax):
    plot_df = pd.DataFrame({"pred": score, 
                            "label": np.where(label > 0, 1, 0), 
                            "spline": spline})
    plot_df["pred_int"] = (plot_df["pred"]).astype(int)
    plot_df = plot_df.groupby('pred_int', as_index=False)['spline','label'].mean()
    
    ax.plot(plot_df.pred_int,plot_df.spline, label='Spline')
    ax.plot(plot_df.pred_int,plot_df.label, label='Score')
    ax.legend()
    ax.set_xlabel('Predicted score')
    ax.set_ylabel('Predicted probability')
    
    return ax


def plot_pred_prob(oof, test, y_train, y_test):
    
    fig, ax = plt.subplots(1,2, figsize=(15, 6))
    
    df = pd.DataFrame()
    df['true'] = np.where(y_train > 0, 1, 0)
    df['Prediction'] = oof
    
    df[df.true==1]['Prediction'].hist(bins=50, ax=ax[0], alpha=0.5, color='g', label='Victory')
    df[df.true==0]['Prediction'].hist(bins=50, ax=ax[0], alpha=0.5, color='r', label='Loss')
    
    df = pd.DataFrame()
    df['true'] = np.where(y_test > 0, 1, 0)
    df['Prediction'] = test

    df[df.true==1]['Prediction'].hist(bins=50, ax=ax[1], alpha=0.5, color='g', label='Victory')
    df[df.true==0]['Prediction'].hist(bins=50, ax=ax[1], alpha=0.5, color='r', label='Loss')
    
    ax[0].axvline(0.5, color='k', linestyle='--')
    ax[1].axvline(0.5, color='k', linestyle='--')
    
    ax[0].set_title('Training data')
    ax[1].set_title('Test data')
    ax[0].grid(False)
    ax[1].grid(False)
    ax[0].legend()
    ax[1].legend()
    fig.suptitle('Probabilities of victory', fontsize=15)
    
    
def report_points(train, test, y_train, y_test, oof, preds, plot=True):
    mae_oof = round(mean_absolute_error(y_true=y_train, y_pred=oof), 4)
    mae_test = round(mean_absolute_error(y_true=y_test, y_pred=preds), 4)
    mse_oof = round(np.sqrt(mean_squared_error(y_true=y_train, y_pred=oof)), 4)
    mse_test = round(np.sqrt(mean_squared_error(y_true=y_test, y_pred=preds)), 4)
    acc_oof = round(accuracy_score(y_true=(y_train>0).astype(int), y_pred=(oof>0).astype(int)),4)
    acc_test = round(accuracy_score(y_true=(y_test>0).astype(int), y_pred=(preds>0).astype(int)),4)
    n_unsure_oof = round((abs(oof) < 1).mean() * 100, 2)
    n_unsure_test = round((abs(preds) < 1).mean() * 100, 2)
    
    # transform into probabilities
    spline_oof, spline_test = _point_to_proba(oof, y_train, preds)
    
    logloss_oof = round(log_loss(y_true=np.where(y_train > 0, 1, 0), y_pred=spline_oof), 4)
    logloss_test = round(log_loss(y_true=np.where(y_test > 0, 1, 0), y_pred=spline_test), 4)
    
    if plot:
        # plot_proba
        fig, ax = plt.subplots(1,2, figsize=(15, 6))

        ax[0] = _plot_proba(oof, y_train, spline_oof, ax[0])
        ax[0].set_title('Training data')

        ax[1] = _plot_proba(preds, y_test, spline_test, ax[1])
        ax[1].set_title('Test data')

        fig.suptitle('Probabilities of victory via splines', fontsize=15)

        # plot predictions
        rp.plot_predictions(train, y_train, oof, savename=False)
        rp.plot_predictions(test, y_test, preds, savename=False)
        
        plot_pred_prob(spline_oof, spline_test, y_train, y_test)
    
    print(f'MAE train: \t\t\t {mae_oof}')
    print(f'MAE test: \t\t\t {mae_test}')
    print(f'RMSE train: \t\t\t {mse_oof}')
    print(f'RMSE test: \t\t\t {mse_test}')
    print(f'Accuracy train: \t\t {acc_oof}')
    print(f'Accuracy test: \t\t\t {acc_test}')
    print(f'Logloss train: \t\t\t {logloss_oof}')
    print(f'Logloss test: \t\t\t {logloss_test}')
    print(f'Unsure train: \t\t\t {n_unsure_oof}%')
    print(f'Unsure test: \t\t\t {n_unsure_test}%')

# %%
report_points(train, test, y_train, y_test, oof_pred, test_pred)
# Out:
# MAE train: 			 8.9953
# MAE test: 			 9.1346
# RMSE train: 			 11.5693
# RMSE test: 			 11.4125
# Accuracy train: 		 0.7024
# Accuracy test: 			 0.6749
# Logloss train: 			 0.5503
# Logloss test: 			 0.5562
# Unsure train: 			 10.03%
# Unsure test: 			 9.42%

# %%
pipe = Pipeline([('scl', df_p.df_scaler()), ('logit', LogisticRegression(solver='lbfgs', multi_class='auto'))])

fitted, oof_pred, test_pred, imp_coef, train, y_train, test, y_test = random_split(df_train, pipe, kfolds, 'target', predict_proba=True)

# %%
imp_coef
# Out:
#                  mean       std
# feat
# delta_Seed  -1.223869  0.013223
# delta_Score  0.073611  0.023561

# %%
def report_victory(y_train, y_test, oof, preds, probs=True):
    
    if probs:
        acc_oof = round(accuracy_score(y_true=y_train, y_pred=(oof>0.5).astype(int)),4)
        acc_test = round(accuracy_score(y_true=y_test, y_pred=(preds>0.5).astype(int)),4)
        n_unsure_oof = round((abs(oof - 0.5) < 0.05).mean() * 100, 4)
        n_unsure_test = round((abs(preds - 0.5) < 0.05).mean() * 100, 4)
        logloss_oof = round(log_loss(y_true=y_train, y_pred=oof), 4)
        logloss_test = round(log_loss(y_true=y_test, y_pred=preds), 4)
        
        plot_pred_prob(oof, preds, y_train, y_test)
    
    print(f'Accuracy train: \t\t {acc_oof}')
    print(f'Accuracy test: \t\t\t {acc_test}')
    print(f'Logloss train: \t\t\t {logloss_oof}')
    print(f'Logloss test: \t\t\t {logloss_test}')
    print(f'Unsure train: \t\t\t {n_unsure_oof}%')
    print(f'Unsure test: \t\t\t {n_unsure_test}%')

# %%
report_victory(y_train, y_test, oof_pred, test_pred)
# Out:
# Accuracy train: 		 0.7068
# Accuracy test: 			 0.6749
# Logloss train: 			 0.5556
# Logloss test: 			 0.5653
# Unsure train: 			 15.1906%
# Unsure test: 			 15.2466%

# %%
def yearly_split(data, model, kfolds, target, predict_proba=False):
    
    fit_model = {}
    oof = {}
    imp_coef = {}
    train = {}
    test = {}
    y_train = {}
    y_test = {}
    predictions = {}
    
    for year in data.Season.unique():
        yr = str(year)
        train[yr] = data[data.Season != year].copy()
        test[yr] = data[data.Season == year].copy()
    
        y_train[yr] = train[yr][target]
        y_test[yr] = test[yr][target]

        train[yr], test[yr] = _clean_columns(train[yr], test[yr])
        
        fit_model[yr], oof[yr], imp_coef[yr], predictions[yr] = _make_preds(train[yr], 
                                                                            y_train[yr], 
                                                                            test[yr], 
                                                                            model, 
                                                                            kfolds, 
                                                                            predict_proba)
    
    return fit_model, oof, predictions, imp_coef, train, y_train, test, y_test

# %%
pipe = Pipeline([('scl', df_p.df_scaler()), ('ridge', Ridge())])

fitted, oof_pred, test_pred, imp_coef, train, y_train, test, y_test = yearly_split(df_train, pipe, kfolds, 'target_points')

# %%
fitted.keys()
# Out:
# dict_keys(['2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019'])

# %%
def yearly_wrapper(train, test, y_train, y_test, oof, preds):
    y_train_total = []
    y_test_total = []
    oof_total = []
    preds_total = []
    for yr in train.keys():
        print(yr)
        print('\n')
        report_points(train[yr], test[yr], y_train[yr], y_test[yr], oof[yr], preds[yr], plot=False)
        print('\n')
        print('_'*40)
        print('\n')
        y_train_total.append(y_train[yr])
        y_test_total.append(y_test[yr])
        oof_total += list(oof[yr])
        preds_total += list(preds[yr])
        
    print('Total predictions')
    print('\n')
    y_train_total = pd.concat(y_train_total, ignore_index=True)
    y_test_total = pd.concat(y_test_total, ignore_index=True)
    oof_total = pd.Series(oof_total)
    preds_total = pd.Series(preds_total)
    report_points(train[yr], test[yr], y_train_total, y_test_total, oof_total, preds_total, plot=True)

# %%
yearly_wrapper(train, test, y_train, y_test, oof_pred, test_pred)
# Out:
# 2003
#
#
# MAE train: 			 9.0331
# MAE test: 			 9.0556
# RMSE train: 			 11.5485
# RMSE test: 			 11.5802
# Accuracy train: 		 0.7003
# Accuracy test: 			 0.6562
# Logloss train: 			 0.5544
# Logloss test: 			 0.5154
# Unsure train: 			 9.66%
# Unsure test: 			 7.81%
#
#
# ________________________________________
#
#
# 2004
#
#
# MAE train: 			 9.0734
# MAE test: 			 8.2924
# RMSE train: 			 11.6007
# RMSE test: 			 10.5745
# Accuracy train: 		 0.6951
# Accuracy test: 			 0.75
# Logloss train: 			 0.5546
# Logloss test: 			 0.5104
# Unsure train: 			 9.8%
# Unsure test: 			 4.69%
#
#
# ________________________________________
#
#
# 2005
#
#
# MAE train: 			 9.1184
# MAE test: 			 7.5995
# RMSE train: 			 11.6531
# RMSE test: 			 9.5868
# Accuracy train: 		 0.6979
# Accuracy test: 			 0.7031
# Logloss train: 			 0.5527
# Logloss test: 			 0.5399
# Unsure train: 			 9.75%
# Unsure test: 			 4.69%
#
#
# ________________________________________
#
#
# 2006
#
#
# MAE train: 			 9.0467
# MAE test: 			 8.815
# RMSE train: 			 11.6021
# RMSE test: 			 10.5651
# Accuracy train: 		 0.6993
# Accuracy test: 			 0.6562
# Logloss train: 			 0.5506
# Logloss test: 			 0.5772
# Unsure train: 			 9.66%
# Unsure test: 			 7.81%
#
#
# ________________________________________
#
#
# 2007
#
#
# MAE train: 			 9.1071
# MAE test: 			 7.7797
# RMSE train: 			 11.6113
# RMSE test: 			 10.3803
# Accuracy train: 		 0.6917
# Accuracy test: 			 0.8125
# Logloss train: 			 0.5579
# Logloss test: 			 0.4586
# Unsure train: 			 10.47%
# Unsure test: 			 7.81%
#
#
# ________________________________________
#
#
# 2008
#
#
# MAE train: 			 8.9242
# MAE test: 			 10.7198
# RMSE train: 			 11.4621
# RMSE test: 			 12.8399
# Accuracy train: 		 0.6955
# Accuracy test: 			 0.7812
# Logloss train: 			 0.5538
# Logloss test: 			 0.5223
# Unsure train: 			 9.56%
# Unsure test: 			 10.94%
#
#
# ________________________________________
#
#
# 2009
#
#
# MAE train: 			 9.0216
# MAE test: 			 9.0914
# RMSE train: 			 11.5096
# RMSE test: 			 12.057
# Accuracy train: 		 0.6965
# Accuracy test: 			 0.7344
# Logloss train: 			 0.5555
# Logloss test: 			 0.4943
# Unsure train: 			 10.23%
# Unsure test: 			 7.81%
#
#
# ________________________________________
#
#
# 2010
#
#
# MAE train: 			 9.0753
# MAE test: 			 8.2658
# RMSE train: 			 11.6023
# RMSE test: 			 10.518
# Accuracy train: 		 0.7008
# Accuracy test: 			 0.6719
# Logloss train: 			 0.5509
# Logloss test: 			 0.5702
# Unsure train: 			 10.04%
# Unsure test: 			 3.12%
#
#
# ________________________________________
#
#
# 2011
#
#
# MAE train: 			 9.0353
# MAE test: 			 9.0241
# RMSE train: 			 11.5457
# RMSE test: 			 11.6286
# Accuracy train: 		 0.699
# Accuracy test: 			 0.6866
# Logloss train: 			 0.5501
# Logloss test: 			 0.5901
# Unsure train: 			 9.73%
# Unsure test: 			 16.42%
#
#
# ________________________________________
#
#
# 2012
#
#
# MAE train: 			 9.096
# MAE test: 			 8.1417
# RMSE train: 			 11.6427
# RMSE test: 			 10.0476
# Accuracy train: 		 0.6985
# Accuracy test: 			 0.6866
# Logloss train: 			 0.5501
# Logloss test: 			 0.5937
# Unsure train: 			 9.54%
# Unsure test: 			 10.45%
#
#
# ________________________________________
#
#
# 2013
#
#
# MAE train: 			 8.8785
# MAE test: 			 11.4713
# RMSE train: 			 11.3616
# RMSE test: 			 14.164
# Accuracy train: 		 0.7009
# Accuracy test: 			 0.6716
# Logloss train: 			 0.5492
# Logloss test: 			 0.6072
# Unsure train: 			 9.83%
# Unsure test: 			 13.43%
#
#
# ________________________________________
#
#
# 2014
#
#
# MAE train: 			 9.0065
# MAE test: 			 9.4255
# RMSE train: 			 11.5475
# RMSE test: 			 11.4977
# Accuracy train: 		 0.7032
# Accuracy test: 			 0.6119
# Logloss train: 			 0.5481
# Logloss test: 			 0.6134
# Unsure train: 			 9.97%
# Unsure test: 			 7.46%
#
#
# ________________________________________
#
#
# 2015
#
#
# MAE train: 			 9.1178
# MAE test: 			 7.6544
# RMSE train: 			 11.6329
# RMSE test: 			 10.0697
# Accuracy train: 		 0.6947
# Accuracy test: 			 0.7463
# Logloss train: 			 0.5536
# Logloss test: 			 0.5295
# Unsure train: 			 9.45%
# Unsure test: 			 16.42%
#
#
# ________________________________________
#
#
# 2016
#
#
# MAE train: 			 8.9383
# MAE test: 			 10.5377
# RMSE train: 			 11.3928
# RMSE test: 			 13.762
# Accuracy train: 		 0.7023
# Accuracy test: 			 0.6418
# Logloss train: 			 0.5496
# Logloss test: 			 0.597
# Unsure train: 			 9.73%
# Unsure test: 			 13.43%
#
#
# ________________________________________
#
#
# 2017
#
#
# MAE train: 			 9.0862
# MAE test: 			 8.2207
# RMSE train: 			 11.5814
# RMSE test: 			 11.0383
# Accuracy train: 		 0.6956
# Accuracy test: 			 0.7313
# Logloss train: 			 0.5542
# Logloss test: 			 0.5265
# Unsure train: 			 9.54%
# Unsure test: 			 13.43%
#
#
# ________________________________________
#
#
# 2018
#
#
# MAE train: 			 8.9986
# MAE test: 			 9.5409
# RMSE train: 			 11.4827
# RMSE test: 			 12.4565
# Accuracy train: 		 0.6999
# Accuracy test: 			 0.6567
# Logloss train: 			 0.5475
# Logloss test: 			 0.6175
# Unsure train: 			 9.54%
# Unsure test: 			 10.45%
#
#
# ________________________________________
#
#
# 2019
#
#
# MAE train: 			 8.9764
# MAE test: 			 9.859
# RMSE train: 			 11.5019
# RMSE test: 			 12.1898
# Accuracy train: 		 0.6999
# Accuracy test: 			 0.6866
# Logloss train: 			 0.5541
# Logloss test: 			 0.5192
# Unsure train: 			 9.54%
# Unsure test: 			 13.43%
#
#
# ________________________________________
#
#
# Total predictions
# MAE train: 			 9.0314
# MAE test: 			 9.0361
# RMSE train: 			 11.5462
# RMSE test: 			 11.5489
# Accuracy train: 		 0.6983
# Accuracy test: 			 0.6987
# Logloss train: 			 0.5522
# Logloss test: 			 0.5521
# Unsure train: 			 9.77%
# Unsure test: 			 10.04%

# %%
pipe = Pipeline([('scl', df_p.df_scaler()), ('logit', LogisticRegression(solver='lbfgs', multi_class='auto'))])

fitted, oof_pred, test_pred, imp_coef, train, y_train, test, y_test = yearly_split(df_train, pipe, kfolds, 'target', predict_proba=True)
