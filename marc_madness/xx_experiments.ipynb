# %%
import pandas as pd
import numpy as np

import source.utility as ut
import source.transf_univ as df_p
import source.report as rp
from source.validate import random_split, yearly_split

from sklearn.model_selection import KFold
from scipy.interpolate import UnivariateSpline

from sklearn.linear_model import Lasso, Ridge, LogisticRegression
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor, ExtraTreesClassifier, ExtraTreesRegressor
from xgboost import XGBRegressor, XGBClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

import matplotlib.pyplot as plt
# %matplotlib inline

pd.set_option('max_columns', 300)

kfolds = KFold(n_splits=5, shuffle=True, random_state=345)

# %%
df = pd.read_csv('data/processed_women/training_data.csv')

df.head()
# Out:
#    Season  DayNum  Team1  Team2  target  target_points  T1_Loc  T2_Loc  \
# 0    2010     138   3124   3201       1             14       0       0
# 1    2010     138   3173   3395       1              1       0       0
# 2    2010     138   3181   3214       1             35       1      -1
# 3    2010     138   3199   3256       1             14       1      -1
# 4    2010     138   3207   3265       1             20       0       0
#
#                ID   T1_Score     T1_FGM     T1_FGA   T1_FGM3    T1_FGA3  \
# 0  2010_3124_3201  72.093750  26.093750  56.343750  2.468750   8.656250
# 1  2010_3173_3395  70.769231  25.884615  61.538462  5.461538  17.461538
# 2  2010_3181_3214  71.593750  26.843750  63.750000  4.562500  14.468750
# 3  2010_3199_3256  74.466667  26.400000  59.200000  6.100000  16.100000
# 4  2010_3207_3265  68.033333  23.833333  60.266667  6.333333  20.066667
#
#       T1_FTM     T1_FTA      T1_OR      T1_DR     T1_Ast      T1_TO  \
# 0  17.437500  24.000000  12.187500  31.062500  14.687500  16.875000
# 1  13.538462  19.346154  14.730769  28.076923  14.461538  16.961538
# 2  13.343750  20.156250  17.718750  25.593750  14.250000  17.906250
# 3  15.566667  21.800000  14.400000  27.266667  15.333333  19.033333
# 4  14.033333  19.533333  15.766667  19.466667  15.866667  16.300000
#
#       T1_Stl    T1_Blk      T1_PF    T1_FGM2    T1_FGA2  T1_Tot_Reb  \
# 0   6.968750  7.250000  14.125000  23.625000  47.687500   43.250000
# 1   7.730769  4.076923  16.576923  20.423077  44.076923   42.807692
# 2  13.375000  5.281250  17.687500  22.281250  49.281250   43.312500
# 3   8.833333  4.033333  17.133333  20.300000  43.100000   41.666667
# 4  13.366667  2.600000  18.033333  17.500000  40.200000   35.233333
#
#    T1_FGM_no_ast  T1_possessions  T1_off_rating  T1_scoring_opp  \
# 0      11.406250       49.631250     150.008679        1.401828
# 1      11.423077       54.579808     132.401257        1.324406
# 2      12.593750       54.363281     133.425214        1.369102
# 3      11.066667       53.478333     141.970006        1.324497
# 4       7.966667       51.521667     134.075369        1.372168
#
#    T1_TO_perposs  T1_def_rating  T1_impact  T1_Def_effort  T1_Reb_opp  \
# 0       0.345379      99.044622   0.686364      89.435245    0.752087
# 1       0.311705     106.419367   0.593500      84.917712    0.763468
# 2       0.332400     101.933460   0.619006      81.564377    0.739992
# 3       0.356610     108.472412   0.625332      86.940374    0.720585
# 4       0.316003     113.007845   0.520921      74.021542    0.670805
#
#    T1_Score_diff  T1_FGM_diff  T1_FGA_diff  T1_FGM3_diff  T1_FGA3_diff  \
# 0      15.250000     4.968750    -6.281250     -3.062500    -11.281250
# 1      11.269231     4.307692     2.846154      0.038462      0.615385
# 2      16.531250     8.000000    10.156250     -0.750000     -2.125000
# 3      14.366667     5.066667    -0.366667      0.800000     -2.333333
# 4       9.666667     4.100000    11.400000      0.933333      1.233333
#
#    T1_FTM_diff  T1_FTA_diff  T1_OR_diff  T1_DR_diff  T1_Ast_diff  T1_TO_diff  \
# 0     8.375000    10.812500   -0.500000    9.281250     5.187500    1.156250
# 1     2.615385     2.769231    2.653846    4.307692     2.807692   -1.384615
# 2     1.281250     2.031250    5.218750    3.625000     2.875000   -5.312500
# 3     3.433333     4.333333    1.000000    6.100000     3.100000   -0.166667
# 4     0.533333     0.766667    3.666667   -3.433333     2.600000   -8.300000
#
#    T1_Stl_diff  T1_Blk_diff  T1_PF_diff  T1_FGM2_diff  T1_FGA2_diff  \
# 0     0.312500     5.375000   -5.125000      8.031250      5.000000
# 1     0.115385    -0.307692   -1.653846      4.269231      2.230769
# 2     5.843750     2.000000   -0.187500      8.750000     12.281250
# 3     0.633333     1.900000   -1.800000      4.266667      1.966667
# 4     5.433333    -0.633333    1.066667      3.166667     10.166667
#
#    T1_Tot_Reb_diff  T1_FGM_no_ast_diff  T1_Def_effort_diff  T1_Reb_opp_diff  \
# 0         8.781250           -0.218750           14.875960         0.030446
# 1         6.961538            1.500000            4.507869         0.095918
# 2         8.843750            5.125000            5.722988         0.139467
# 3         7.100000            1.966667           10.181274         0.069396
# 4         0.233333            1.500000           -7.032081         0.039055
#
#    T1_possessions_diff  T1_off_rating_diff  T1_def_rating_diff  \
# 0            -9.760938           50.964056          -50.964056
# 1            -2.507692           25.981890          -25.981890
# 2            -1.339844           31.491754          -31.491754
# 3            -3.591667           33.497594          -33.497594
# 4            -0.930833           21.067524          -21.067524
#
#    T1_scoring_opp_diff  T1_TO_perposs_diff  T1_impact_diff  T1_N_wins  \
# 0             0.213604            0.083225        0.372728   0.718750
# 1             0.140615           -0.012195        0.187000   0.807692
# 2             0.230749           -0.086185        0.238011   0.843750
# 3             0.111108            0.017835        0.250665   0.833333
# 4             0.250068           -0.152776        0.041843   0.800000
#
#    T1_FGM_perc  T1_FGM2_perc  T1_FGM3_perc  T1_FT_perc  T1_FGM_no_ast_perc  \
# 0     0.463117      0.495413      0.285199    0.726562            0.437126
# 1     0.420625      0.463351      0.312775    0.699801            0.441308
# 2     0.421078      0.452124      0.315335    0.662016            0.469150
# 3     0.445946      0.470998      0.378882    0.714067            0.419192
# 4     0.395465      0.435323      0.315615    0.718430            0.334266
#
#    T1_L2W_Score  T1_L2W_FGM  T1_L2W_FGA  T1_L2W_FGM3  T1_L2W_FGA3  T1_L2W_FTM  \
# 0         63.80        22.6       56.00         2.40         10.8        16.2
# 1         73.50        26.5       57.00         7.00         19.5        13.5
# 2         64.25        23.0       60.75         5.25         15.0        13.0
# 3         77.00        26.5       65.00         8.00         22.0        16.0
# 4         63.50        21.5       60.00         8.50         24.0        12.0
#
#    T1_L2W_FTA  T1_L2W_OR  T1_L2W_DR  T1_L2W_Ast  T1_L2W_TO  T1_L2W_Stl  \
# 0       21.60       11.4      28.00       12.80      14.40         6.2
# 1       17.50       11.5      29.50       14.50      15.50         3.0
# 2       22.25       16.5      20.25       11.75      18.25        14.5
# 3       19.50       17.5      20.50       13.00      13.50        10.5
# 4       16.00       13.5      23.00       14.50      16.00        11.5
#
#    T1_L2W_Blk  T1_L2W_PF  T1_L2W_FGM2  T1_L2W_FGA2  T1_L2W_Tot_Reb  \
# 0         6.2       14.2        20.20        45.20           39.40
# 1         3.5       21.0        19.50        37.50           41.00
# 2         4.5       19.5        17.75        45.75           36.75
# 3         1.0       17.5        18.50        43.00           38.00
# 4         2.0       20.0        13.00        36.00           36.50
#
#    T1_L2W_FGM_no_ast  T1_L2W_possessions  T1_L2W_off_rating  \
# 0               9.80            48.74000         131.662173
# 1              12.00            52.68750         139.979276
# 2              11.25            51.93125         126.373070
# 3              13.50            51.73750         147.335225
# 4               7.00            54.90000         115.842829
#
#    T1_L2W_scoring_opp  T1_L2W_TO_perposs  T1_L2W_def_rating  T1_L2W_impact  \
# 0            1.362544           0.296796         109.114274       0.554120
# 1            1.242899           0.292839         149.147173       0.607832
# 2            1.384607           0.346208         119.574558       0.498405
# 3            1.453876           0.256441         119.129078       0.491874
# 4            1.229162           0.291480         122.373821       0.521595
#
#    T1_L2W_Def_effort  T1_L2W_Reb_opp  T1_L2W_Score_diff  T1_L2W_FGM_diff  \
# 0          80.180892        0.810323                3.6             0.00
# 1          94.861685        0.750464                7.0             5.00
# 2          75.813283        0.645238                3.5             3.75
# 3          76.121705        0.710859               13.0             4.00
# 4          96.693182        0.645833                7.5             5.50
#
#    T1_L2W_FGA_diff  T1_L2W_FGM3_diff  T1_L2W_FGA3_diff  T1_L2W_FTM_diff  \
# 0            -1.80             -2.00             -3.60             5.60
# 1            -5.50              3.00              7.00            -6.00
# 2            10.25             -0.25              0.75            -3.75
# 3            13.50              0.50              1.00             4.50
# 4             8.50              4.50              3.00            -8.00
#
#    T1_L2W_FTA_diff  T1_L2W_OR_diff  T1_L2W_DR_diff  T1_L2W_Ast_diff  \
# 0              7.0             1.2            3.20              1.8
# 1             -9.5            -4.5            9.00              5.0
# 2              0.0             3.5           -2.25              2.0
# 3              4.0             8.5           -1.50              1.0
# 4            -10.0            -0.5           -2.00              3.5
#
#    T1_L2W_TO_diff  T1_L2W_Stl_diff  T1_L2W_Blk_diff  T1_L2W_PF_diff  \
# 0           -0.20             -0.4              3.0            -3.4
# 1            4.00             -4.0             -1.0             2.5
# 2           -6.25              6.5              0.5             0.0
# 3           -7.00              5.0             -4.5             0.0
# 4           -5.00              5.5             -1.5             3.0
#
#    T1_L2W_FGM2_diff  T1_L2W_FGA2_diff  T1_L2W_Tot_Reb_diff  \
# 0               2.0               1.8                 4.40
# 1               2.0             -12.5                 4.50
# 2               4.0               9.5                 1.25
# 3               3.5              12.5                 7.00
# 4               1.0               5.5                -2.50
#
#    T1_L2W_FGM_no_ast_diff  T1_L2W_Def_effort_diff  T1_L2W_Reb_opp_diff  \
# 0                   -1.80               -1.072316             0.058532
# 1                    0.00               20.760569             0.077845
# 2                    1.75               -9.205988             0.036975
# 3                    3.00               -3.110263             0.106313
# 4                    2.00               10.276327             0.009537
#
#    T1_L2W_possessions_diff  T1_L2W_off_rating_diff  T1_L2W_def_rating_diff  \
# 0                  -6.5250               22.547899              -22.547899
# 1                   7.5125               -9.167897                9.167897
# 2                   0.5000                6.798512               -6.798512
# 3                  -3.9000               28.206147              -28.206147
# 4                   8.7500               -6.530993                6.530993
#
#    T1_L2W_scoring_opp_diff  T1_L2W_TO_perposs_diff  T1_L2W_impact_diff  \
# 0                 0.186271                0.035159            0.108240
# 1                -0.426369                0.030717            0.215665
# 2                 0.184578               -0.137259           -0.003191
# 3                 0.385886               -0.114645           -0.016253
# 4                -0.166403               -0.165701            0.043190
#
#    T1_L2W_N_wins  T1_L2W_FGM_perc  T1_L2W_FGM2_perc  T1_L2W_FGM3_perc  \
# 0           0.60         0.403571          0.446903          0.222222
# 1           0.50         0.464912          0.520000          0.358974
# 2           0.75         0.378601          0.387978          0.350000
# 3           0.50         0.407692          0.430233          0.363636
# 4           0.50         0.358333          0.361111          0.354167
#
#    T1_L2W_FT_perc  T1_L2W_FGM_no_ast_perc  T1_Seed   T2_Score     T2_FGM  \
# 0        0.750000                0.433628      4.0  73.454545  25.848485
# 1        0.771429                0.452830      8.0  72.300000  25.833333
# 2        0.584270                0.489130      2.0  62.833333  22.200000
# 3        0.820513                0.509434      3.0  74.258065  27.161290
# 4        0.750000                0.325581      5.0  68.181818  23.424242
#
#       T2_FGA   T2_FGM3    T2_FGA3     T2_FTM     T2_FTA      T2_OR      T2_DR  \
# 0  61.575758  8.818182  24.848485  12.939394  18.242424  13.878788  24.575758
# 1  62.266667  6.866667  19.200000  13.766667  18.400000  13.500000  25.833333
# 2  60.100000  4.900000  16.100000  13.533333  18.933333  14.966667  22.666667
# 3  62.516129  3.935484  12.451613  16.000000  23.354839  14.806452  29.741935
# 4  55.696970  6.545455  19.030303  14.787879  18.484848  10.515152  26.303030
#
#       T2_Ast      T2_TO     T2_Stl    T2_Blk      T2_PF    T2_FGM2    T2_FGA2  \
# 0  14.636364  15.636364  10.393939  2.606061  16.393939  17.030303  36.727273
# 1  15.600000  16.033333   9.833333  3.600000  16.233333  18.966667  43.066667
# 2  11.600000  15.533333  10.100000  2.233333  18.833333  17.300000  44.000000
# 3  14.516129  17.096774   7.096774  3.741935  16.032258  23.225806  50.064516
# 4  14.454545  13.484848   7.878788  4.484848  13.969697  16.878788  36.666667
#
#    T2_Tot_Reb  T2_FGM_no_ast  T2_possessions  T2_off_rating  T2_scoring_opp  \
# 0   38.454545      11.212121       54.668182     135.755533        1.300159
# 1   39.333333      10.233333       56.060000     130.289967        1.279092
# 2   37.633333      10.600000       51.673333     123.484672        1.355898
# 3   44.548387      12.645161       53.712903     140.984851        1.401465
# 4   36.818182       8.969697       49.886364     138.989376        1.320067
#
#    T2_TO_perposs  T2_def_rating  T2_impact  ...  T2_L2W_FGM_diff  \
# 0       0.290486     108.298303   0.568992  ...         3.500000
# 1       0.286245     106.593105   0.572062  ...        -3.333333
# 2       0.306263     117.315308   0.534738  ...         6.250000
# 3       0.321117     110.377441   0.600541  ...         2.000000
# 4       0.270687     110.083817   0.615449  ...         3.250000
#
#    T2_L2W_FGA_diff  T2_L2W_FGM3_diff  T2_L2W_FGA3_diff  T2_L2W_FTM_diff  \
# 0        12.000000              6.50         14.000000              5.5
# 1         3.333333              1.00          2.666667              4.0
# 2         7.750000              2.25          7.250000              2.0
# 3        -4.400000             -1.60         -8.400000              1.6
# 4        -5.500000              0.25         -5.000000              7.0
#
#    T2_L2W_FTA_diff  T2_L2W_OR_diff  T2_L2W_DR_diff  T2_L2W_Ast_diff  \
# 0         0.750000        4.000000           -1.25         1.500000
# 1         4.333333       -1.333333           -8.00        -4.333333
# 2        -2.000000        0.000000            0.50         6.500000
# 3         5.400000       -0.800000            3.40         0.200000
# 4         9.500000       -6.250000            2.00         4.000000
#
#    T2_L2W_TO_diff  T2_L2W_Stl_diff  T2_L2W_Blk_diff  T2_L2W_PF_diff  \
# 0       -7.500000             4.50         1.500000        4.250000
# 1       -5.666667             1.00        -3.333333       -1.333333
# 2       -7.250000             3.75         2.000000       -0.250000
# 3        0.800000             1.00        -0.800000       -3.200000
# 4       -4.000000             1.25         2.250000       -7.000000
#
#    T2_L2W_FGM2_diff  T2_L2W_FGA2_diff  T2_L2W_Tot_Reb_diff  \
# 0         -3.000000         -2.000000             2.750000
# 1         -4.333333          0.666667            -9.333333
# 2          4.000000          0.500000             0.500000
# 3          3.600000          4.000000             2.600000
# 4          3.000000         -0.500000            -4.250000
#
#    T2_L2W_FGM_no_ast_diff  T2_L2W_Def_effort_diff  T2_L2W_Reb_opp_diff  \
# 0                    2.00              -12.482590             0.161982
# 1                    1.00              -25.267530            -0.065727
# 2                   -0.25               -2.074616             0.036773
# 3                    1.80                7.337721            -0.032864
# 4                   -0.75               -7.024617            -0.121996
#
#    T2_L2W_possessions_diff  T2_L2W_off_rating_diff  T2_L2W_def_rating_diff  \
# 0                 0.143750               34.639212              -34.639212
# 1                -3.058333               -2.944339                2.944339
# 2                 1.450000               31.847440              -31.847440
# 3                -5.365000               21.777253              -21.777253
# 4                -7.762500               45.519063              -45.519063
#
#    T2_L2W_scoring_opp_diff  T2_L2W_TO_perposs_diff  T2_L2W_impact_diff  \
# 0                 0.227082               -0.139179            0.145736
# 1                 0.145358               -0.101780           -0.176167
# 2                 0.104104               -0.160401            0.374995
# 3                 0.116811                0.035698            0.080471
# 4                 0.206073               -0.044765            0.325198
#
#    T2_L2W_N_wins  T2_L2W_FGM_perc  T2_L2W_FGM2_perc  T2_L2W_FGM3_perc  \
# 0       0.750000         0.395683          0.401198          0.387387
# 1       0.333333         0.346821          0.357143          0.327869
# 2       1.000000         0.405530          0.471338          0.233333
# 3       0.800000         0.442675          0.470356          0.327869
# 4       0.750000         0.417840          0.456376          0.328125
#
#    T2_L2W_FT_perc  T2_L2W_FGM_no_ast_perc  T2_Seed  delta_Loc  delta_Score  \
# 0        0.731343                0.436364     13.0          0    -1.360795
# 1        0.800000                0.316667      9.0          0    -1.530769
# 2        0.725806                0.488636     15.0          2     8.760417
# 3        0.631579                0.482014     14.0          2     0.208602
# 4        0.733333                0.438202     12.0          0    -0.148485
#
#    delta_FGM  delta_FGA  delta_FGM3  delta_FGA3  delta_FTM  delta_FTA  \
# 0   0.245265  -5.232008   -6.349432  -16.192235   4.498106   5.757576
# 1   0.051282  -0.728205   -1.405128   -1.738462  -0.228205   0.946154
# 2   4.643750   3.650000   -0.337500   -1.631250  -0.189583   1.222917
# 3  -0.761290  -3.316129    2.164516    3.648387  -0.433333  -1.554839
# 4   0.409091   4.569697   -0.212121    1.036364  -0.754545   1.048485
#
#    delta_OR  delta_DR  delta_Ast  delta_TO  delta_Stl  delta_Blk  delta_PF  \
# 0 -1.691288  6.486742   0.051136  1.238636  -3.425189   4.643939 -2.268939
# 1  1.230769  2.243590  -1.138462  0.928205  -2.102564   0.476923  0.343590
# 2  2.752083  2.927083   2.650000  2.372917   3.275000   3.047917 -1.145833
# 3 -0.406452 -2.475269   0.817204  1.936559   1.736559   0.291398  1.101075
# 4  5.251515 -6.836364   1.412121  2.815152   5.487879  -1.884848  4.063636
#
#    delta_FGM2  delta_FGA2  delta_Tot_Reb  delta_FGM_no_ast  delta_possessions  \
# 0    6.594697   10.960227       4.795455          0.194129          -5.036932
# 1    1.456410    1.010256       3.474359          1.189744          -1.480192
# 2    4.981250    5.281250       5.679167          1.993750           2.689948
# 3   -2.925806   -6.964516      -2.881720         -1.578495          -0.234570
# 4    0.621212    3.533333      -1.584848         -1.003030           1.635303
#
#    delta_off_rating  delta_scoring_opp  delta_TO_perposs  delta_def_rating  \
# 0         14.253145           0.101669          0.054893         -9.253681
# 1          2.111290           0.045315          0.025460         -0.173738
# 2          9.940541           0.013203          0.026137        -15.381848
# 3          0.985155          -0.076967          0.035493         -1.905029
# 4         -4.914006           0.052102          0.045316          2.924028
#
#    delta_impact  delta_Def_effort  delta_Reb_opp  delta_Score_diff  \
# 0      0.117371         13.790648       0.019471          2.371212
# 1      0.021438          2.387353       0.077786         -0.730769
# 2      0.084267          6.128560      -0.004298          8.831250
# 3      0.024791         -3.922407      -0.023702          4.431183
# 4     -0.094528         -8.517123      -0.018726         -0.606061
#
#    delta_FGM_diff  delta_FGA_diff  delta_FGM3_diff  delta_FGA3_diff  \
# 0        2.059659      -11.160038        -7.729167       -22.281250
# 1        0.307692        0.279487        -1.094872         1.582051
# 2        4.800000       -0.010417        -2.783333        -7.891667
# 3        1.808602        1.181720         1.670968         2.602151
# 4        1.251515       14.642424         0.721212         3.566667
#
#    delta_FTM_diff  delta_FTA_diff  delta_OR_diff  delta_DR_diff  \
# 0        5.981061        8.873106      -2.136364       9.523674
# 1       -0.251282        0.669231       4.020513       3.807692
# 2        2.014583        5.097917       2.885417       7.091667
# 3       -0.856989       -1.021505      -0.096774       0.809677
# 4       -3.830303       -2.809091       7.484848      -6.372727
#
#    delta_Ast_diff  delta_TO_diff  delta_Stl_diff  delta_Blk_diff  \
# 0        2.399621       5.398674       -3.323864        5.375000
# 1        0.674359       3.248718       -1.251282       -0.407692
# 2        0.008333       1.287500        2.377083        2.033333
# 3       -0.674194       0.188172        1.730108        2.383871
# 4       -1.127273      -6.057576        4.706061       -2.815152
#
#    delta_PF_diff  delta_FGM2_diff  delta_FGA2_diff  delta_Tot_Reb_diff  \
# 0      -5.276515         9.788826        11.121212            7.387311
# 1      -1.320513         1.402564        -1.302564            7.828205
# 2      -2.320833         7.583333         7.881250            9.977083
# 3       1.845161         0.137634        -1.420430            0.712903
# 4       3.915152         0.530303        11.075758            1.112121
#
#    delta_FGM_no_ast_diff  delta_Def_effort_diff  delta_Reb_opp_diff  \
# 0              -0.339962              24.239464           -0.005337
# 1              -0.366667               4.683931            0.109218
# 2               4.791667              12.741546            0.098469
# 3               2.482796               1.264971            0.022973
# 4               2.378788              -8.775944            0.077118
#
#    delta_possessions_diff  delta_off_rating_diff  delta_def_rating_diff  \
# 0               -7.839725              23.506826             -23.506826
# 1               -0.810192               2.285028              -2.285028
# 2               -4.029844              25.322390             -25.322390
# 3                1.951882               2.890184              -2.890184
# 4                2.434318              -7.838034               7.838034
#
#    delta_scoring_opp_diff  delta_TO_perposs_diff  delta_impact_diff  \
# 0                0.067452               0.144988           0.234743
# 1                0.046769               0.059521           0.042876
# 2                0.145068               0.063929           0.168535
# 3               -0.052903              -0.006285           0.049582
# 4                0.181634              -0.126090          -0.189056
#
#    delta_N_wins  delta_FGM_perc  delta_FGM2_perc  delta_FGM3_perc  \
# 0     -0.099432        0.043334         0.031716        -0.069679
# 1      0.074359        0.005743         0.022948        -0.044864
# 2      0.210417        0.051694         0.058942         0.010987
# 3      0.091398        0.011477         0.007080         0.062820
# 4      0.012121       -0.025101        -0.025007        -0.028334
#
#    delta_FT_perc  delta_FGM_no_ast_perc  delta_L2W_Score  delta_L2W_FGM  \
# 0       0.017260               0.003363       -14.200000          -4.90
# 1      -0.048387               0.045179        10.833333           6.50
# 2      -0.052773              -0.008327         5.500000           1.00
# 3       0.028984              -0.046366         5.400000          -1.30
# 4      -0.081570              -0.048658         0.000000          -0.75
#
#    delta_L2W_FGA  delta_L2W_FGM3  delta_L2W_FGA3  delta_L2W_FTM  \
# 0     -13.500000       -8.350000      -16.950000           3.95
# 1      -0.666667        0.333333       -0.833333          -2.50
# 2       6.500000        1.750000        0.000000           1.75
# 3       2.200000        4.000000        9.800000           4.00
# 4       6.750000        3.250000        8.000000          -1.75
#
#    delta_L2W_FTA  delta_L2W_OR  delta_L2W_DR  delta_L2W_Ast  delta_L2W_TO  \
# 0           4.85     -4.600000          0.75      -2.700000      1.150000
# 1          -2.50      3.166667          5.50       0.833333      3.166667
# 2           6.75      5.500000         -3.50       0.500000      6.250000
# 3           0.50      3.500000         -7.50      -1.400000     -0.900000
# 4          -2.75      5.000000         -2.75       2.000000      6.000000
#
#    delta_L2W_Stl  delta_L2W_Blk  delta_L2W_PF  delta_L2W_FGM2  delta_L2W_FGA2  \
# 0      -4.550000           2.95     -3.800000        3.450000        3.450000
# 1      -4.666667           2.50      4.333333        6.166667        0.166667
# 2       7.000000           0.75      4.750000       -0.750000        6.500000
# 3       2.500000          -2.00      4.100000       -5.300000       -7.600000
# 4       3.750000          -3.00     10.000000       -4.000000       -1.250000
#
#    delta_L2W_Tot_Reb  delta_L2W_FGM_no_ast  delta_L2W_possessions  \
# 0          -3.850000             -2.200000             -10.053750
# 1           8.666667              5.666667               0.520833
# 2           2.000000              0.500000               4.043750
# 3          -4.000000              0.100000              -2.437500
# 4           2.250000             -2.750000               9.056250
#
#    delta_L2W_off_rating  delta_L2W_scoring_opp  delta_L2W_TO_perposs  \
# 0             -3.691077               0.021982              0.073867
# 1             19.294832              -0.052222              0.052854
# 2              2.366887               0.084219              0.090044
# 3             10.599394               0.088079             -0.010403
# 4            -24.764136              -0.167654              0.075315
#
#    delta_L2W_def_rating  delta_L2W_impact  delta_L2W_Def_effort  \
# 0              8.400236         -0.018748              1.710113
# 1             25.518390          0.195916             19.545900
# 2             27.415816         -0.189093              2.727834
# 3              4.170500         -0.048362             -8.351474
# 4             27.285919         -0.141004             21.042688
#
#    delta_L2W_Reb_opp  delta_L2W_Score_diff  delta_L2W_FGM_diff  \
# 0          -0.042454            -15.400000           -3.500000
# 1          -0.038738              8.666667            8.333333
# 2          -0.129765            -13.250000           -2.500000
# 3           0.043099              9.000000            2.000000
# 4           0.003265             -6.250000            2.250000
#
#    delta_L2W_FGA_diff  delta_L2W_FGM3_diff  delta_L2W_FGA3_diff  \
# 0          -13.800000                -8.50           -17.600000
# 1           -8.833333                 2.00             4.333333
# 2            2.500000                -2.50            -6.500000
# 3           17.900000                 2.10             9.400000
# 4           14.000000                 4.25             8.000000
#
#    delta_L2W_FTM_diff  delta_L2W_FTA_diff  delta_L2W_OR_diff  \
# 0                0.10            6.250000          -2.800000
# 1              -10.00          -13.833333          -3.166667
# 2               -5.75            2.000000           3.500000
# 3                2.90           -1.400000           9.300000
# 4              -15.00          -19.500000           5.750000
#
#    delta_L2W_DR_diff  delta_L2W_Ast_diff  delta_L2W_TO_diff  \
# 0               4.45            0.300000           7.300000
# 1              17.00            9.333333           9.666667
# 2              -2.75           -4.500000           1.000000
# 3              -4.90            0.800000          -7.800000
# 4              -4.00           -0.500000          -1.000000
#
#    delta_L2W_Stl_diff  delta_L2W_Blk_diff  delta_L2W_PF_diff  \
# 0               -4.90            1.500000          -7.650000
# 1               -5.00            2.333333           3.833333
# 2                2.75           -1.500000           0.250000
# 3                4.00           -3.700000           3.200000
# 4                4.25           -3.750000          10.000000
#
#    delta_L2W_FGM2_diff  delta_L2W_FGA2_diff  delta_L2W_Tot_Reb_diff  \
# 0             5.000000             3.800000                1.650000
# 1             6.333333           -13.166667               13.833333
# 2             0.000000             9.000000                0.750000
# 3            -0.100000             8.500000                4.400000
# 4            -2.000000             6.000000                1.750000
#
#    delta_L2W_FGM_no_ast_diff  delta_L2W_Def_effort_diff  \
# 0                      -3.80                  11.410274
# 1                      -1.00                  46.028099
# 2                       2.00                  -7.131372
# 3                       1.20                 -10.447984
# 4                       2.75                  17.300944
#
#    delta_L2W_Reb_opp_diff  delta_L2W_possessions_diff  \
# 0               -0.103450                   -6.668750
# 1                0.143572                   10.570833
# 2                0.000202                   -0.950000
# 3                0.139177                    1.465000
# 4                0.131533                   16.512500
#
#    delta_L2W_off_rating_diff  delta_L2W_def_rating_diff  \
# 0                 -12.091312                  12.091312
# 1                  -6.223558                   6.223558
# 2                 -25.048929                  25.048929
# 3                   6.428894                  -6.428894
# 4                 -52.050055                  52.050055
#
#    delta_L2W_scoring_opp_diff  delta_L2W_TO_perposs_diff  \
# 0                   -0.040811                   0.174338
# 1                   -0.571727                   0.132497
# 2                    0.080474                   0.023141
# 3                    0.269075                  -0.150343
# 4                   -0.372476                  -0.120936
#
#    delta_L2W_impact_diff  delta_L2W_N_wins  delta_L2W_FGM_perc  \
# 0              -0.037495         -0.150000            0.007888
# 1               0.391832          0.166667            0.118091
# 2              -0.378186         -0.250000           -0.026929
# 3              -0.096723         -0.300000           -0.034983
# 4              -0.282008         -0.250000           -0.059507
#
#    delta_L2W_FGM2_perc  delta_L2W_FGM3_perc  delta_L2W_FT_perc  \
# 0             0.045705            -0.165165           0.018657
# 1             0.162857             0.031106          -0.028571
# 2            -0.083359             0.116667          -0.141537
# 3            -0.040123             0.035768           0.188934
# 4            -0.095265             0.026042           0.016667
#
#    delta_L2W_FGM_no_ast_perc  delta_Seed
# 0                  -0.002735        -9.0
# 1                   0.136164        -1.0
# 2                   0.000494       -13.0
# 3                   0.027420       -11.0
# 4                  -0.112621        -7.0
#
# [5 rows x 361 columns]

# %%
standard = ['Season', 'target', 'target_points', 'ID']

l2w = [col for col in df if 'L2W' in col and col not in standard]
tot = [col for col in df if 'L2W' not in col and col not in standard]
l2w_deltas = [col for col in df if 'L2W' in col and col not in standard and 'delta' in col]
tot_deltas = [col for col in df if 'L2W' not in col and col not in standard and 'delta' in col]

feat_dict = {'l2w': l2w, 'tot': tot, 'l2w_delta': l2w_deltas, 'tot_delta': tot_deltas}

models = [('lasso', Lasso(alpha=0.1)), 
          ('ridge', Ridge()), 
          ('forest', RandomForestRegressor(n_estimators=200, n_jobs=5)), ('xtree', ExtraTreesRegressor(n_estimators=200, n_jobs=5)), 
          ('xgb', XGBRegressor(n_estimators=100, objective='reg:squarederror'))]

for model in models:
    print('_'*40)
    print(model[0])
    for feats in feat_dict.keys():
        print(f'\t {feats}')
        print('\t'+'-'*30)
        df_train = df[standard + feat_dict[feats]]
        
        pipe = Pipeline([('scl', df_p.df_scaler())] + [model])
        
        fitted, oof_pred, test_pred, imp_coef, train, y_train, test, y_test = random_split(df_train, pipe, kfolds, 'target_points')
        
        rp.report_points(train, test, y_train, y_test, oof_pred, test_pred, plot=False)
        print('\t'+'-'*30)
    print('_'*40)
# Out:
# ________________________________________
# lasso
# 	 l2w
# 	------------------------------
# MAE train: 			 13.8105
# MAE test: 			 15.1821
# RMSE train: 			 17.4357
# RMSE test: 			 19.8434
# Accuracy train: 		 0.6964
# Accuracy test: 			 0.623
# Logloss train: 			 0.5817
# Logloss test: 			 0.619
# Unsure train: 			 6.85%
# Unsure test: 			 9.52%
# 	------------------------------
# 	 tot
# 	------------------------------
# MAE train: 			 9.6414
# MAE test: 			 10.6548
# RMSE train: 			 12.233
# RMSE test: 			 13.3918
# Accuracy train: 		 0.8075
# Accuracy test: 			 0.7579
# Logloss train: 			 0.4163
# Logloss test: 			 0.4818
# Unsure train: 			 5.65%
# Unsure test: 			 7.54%
# 	------------------------------
# 	 l2w_delta
# 	------------------------------
# MAE train: 			 13.5166
# MAE test: 			 14.9475
# RMSE train: 			 17.1183
# RMSE test: 			 19.4619
# Accuracy train: 		 0.7004
# Accuracy test: 			 0.6508
# Logloss train: 			 0.5715
# Logloss test: 			 0.6073
# Unsure train: 			 6.45%
# Unsure test: 			 9.13%
# 	------------------------------
# 	 tot_delta
# 	------------------------------
# MAE train: 			 9.4494
# MAE test: 			 10.493
# RMSE train: 			 12.02
# RMSE test: 			 13.1618
# Accuracy train: 		 0.8056
# Accuracy test: 			 0.7619
# Logloss train: 			 0.4094
# Logloss test: 			 0.4696
# Unsure train: 			 4.66%
# Unsure test: 			 5.95%
# 	------------------------------
# ________________________________________
# ________________________________________
# ridge
# 	 l2w
# 	------------------------------
# MAE train: 			 13.8956
# MAE test: 			 15.187
# RMSE train: 			 17.5574
# RMSE test: 			 19.7721
# Accuracy train: 		 0.6885
# Accuracy test: 			 0.619
# Logloss train: 			 0.5792
# Logloss test: 			 0.6301
# Unsure train: 			 5.85%
# Unsure test: 			 8.73%
# 	------------------------------
# 	 tot
# 	------------------------------
# MAE train: 			 9.9187
# MAE test: 			 10.8457
# RMSE train: 			 12.5825
# RMSE test: 			 13.9203
# Accuracy train: 		 0.8036
# Accuracy test: 			 0.7421
# Logloss train: 			 0.4245
# Logloss test: 			 0.4989
# Unsure train: 			 4.46%
# Unsure test: 			 3.97%
# 	------------------------------
# 	 l2w_delta
# 	------------------------------
# MAE train: 			 13.3533
# MAE test: 			 14.5866
# RMSE train: 			 16.9628
# RMSE test: 			 19.0365
# Accuracy train: 		 0.6915
# Accuracy test: 			 0.6349
# Logloss train: 			 0.5608
# Logloss test: 			 0.6078
# Unsure train: 			 6.65%
# Unsure test: 			 9.52%
# 	------------------------------
# 	 tot_delta
# 	------------------------------
# MAE train: 			 9.4812
# MAE test: 			 10.3494
# RMSE train: 			 12.0856
# RMSE test: 			 13.2148
# Accuracy train: 		 0.8046
# Accuracy test: 			 0.7579
# Logloss train: 			 0.4113
# Logloss test: 			 0.4707
# Unsure train: 			 4.56%
# Unsure test: 			 3.57%
# 	------------------------------
# ________________________________________
# ________________________________________
# forest
# 	 l2w
# 	------------------------------
# MAE train: 			 14.3765
# MAE test: 			 15.6336
# RMSE train: 			 17.8413
# RMSE test: 			 20.2875
# Accuracy train: 		 0.6597
# Accuracy test: 			 0.6111
# Logloss train: 			 0.6148
# Logloss test: 			 0.6399
# Unsure train: 			 9.03%
# Unsure test: 			 10.32%
# 	------------------------------
# 	 tot
# 	------------------------------
# MAE train: 			 10.3137
# MAE test: 			 11.3184
# RMSE train: 			 12.8396
# RMSE test: 			 14.0174
# Accuracy train: 		 0.7877
# Accuracy test: 			 0.7341
# Logloss train: 			 0.4365
# Logloss test: 			 0.4888
# Unsure train: 			 4.46%
# Unsure test: 			 4.37%
# 	------------------------------
# 	 l2w_delta
# 	------------------------------
# MAE train: 			 14.8129
# MAE test: 			 16.4769
# RMSE train: 			 18.4119
# RMSE test: 			 21.5014
# Accuracy train: 		 0.6478
# Accuracy test: 			 0.5913
# Logloss train: 			 0.6272
# Logloss test: 			 0.6634
# Unsure train: 			 9.13%
# Unsure test: 			 9.52%
# 	------------------------------
# 	 tot_delta
# 	------------------------------
# MAE train: 			 10.2338
# MAE test: 			 10.8953
# RMSE train: 			 12.714
# RMSE test: 			 13.7479
# Accuracy train: 		 0.7927
# Accuracy test: 			 0.7302
# Logloss train: 			 0.4305
# Logloss test: 			 0.485
# Unsure train: 			 4.96%
# Unsure test: 			 6.35%
# 	------------------------------
# ________________________________________
# ________________________________________
# xtree
# 	 l2w
# 	------------------------------
# MAE train: 			 14.5237
# MAE test: 			 15.63
# RMSE train: 			 17.9579
# RMSE test: 			 20.2892
# Accuracy train: 		 0.6577
# Accuracy test: 			 0.623
# Logloss train: 			 0.6176
# Logloss test: 			 0.6405
# Unsure train: 			 8.43%
# Unsure test: 			 11.9%
# 	------------------------------
# 	 tot
# 	------------------------------
# MAE train: 			 10.1392
# MAE test: 			 11.0068
# RMSE train: 			 12.6442
# RMSE test: 			 13.6097
# Accuracy train: 		 0.8075
# Accuracy test: 			 0.754
# Logloss train: 			 0.4282
# Logloss test: 			 0.4846
# Unsure train: 			 4.96%
# Unsure test: 			 6.35%
# 	------------------------------
# 	 l2w_delta
# 	------------------------------
# MAE train: 			 14.976
# MAE test: 			 16.2878
# RMSE train: 			 18.5801
# RMSE test: 			 21.3313
# Accuracy train: 		 0.6558
# Accuracy test: 			 0.6071
# Logloss train: 			 0.6295
# Logloss test: 			 0.6623
# Unsure train: 			 8.23%
# Unsure test: 			 9.13%
# 	------------------------------
# 	 tot_delta
# 	------------------------------
# MAE train: 			 10.0278
# MAE test: 			 11.0764
# RMSE train: 			 12.5808
# RMSE test: 			 13.6945
# Accuracy train: 		 0.8026
# Accuracy test: 			 0.754
# Logloss train: 			 0.4271
# Logloss test: 			 0.4822
# Unsure train: 			 3.77%
# Unsure test: 			 4.37%
# 	------------------------------
# ________________________________________
# ________________________________________
# xgb
# 	 l2w
# 	------------------------------
# /home/lucabasa/Git/kaggle_competitions/marc_madness/ncaa/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# /home/lucabasa/Git/kaggle_competitions/marc_madness/ncaa/lib/python3.6/site-packages/xgboost/core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \
# MAE train: 			 14.1688
# MAE test: 			 15.4772
# RMSE train: 			 17.6343
# RMSE test: 			 20.0028
# Accuracy train: 		 0.6577
# Accuracy test: 			 0.6508
# Logloss train: 			 0.6035
# Logloss test: 			 0.6367
# Unsure train: 			 8.53%
# Unsure test: 			 11.9%
# 	------------------------------
# 	 tot
# 	------------------------------
# /home/lucabasa/Git/kaggle_competitions/marc_madness/ncaa/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# /home/lucabasa/Git/kaggle_competitions/marc_madness/ncaa/lib/python3.6/site-packages/xgboost/core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \
# MAE train: 			 10.1703
# MAE test: 			 11.4798
# RMSE train: 			 12.7326
# RMSE test: 			 14.1799
# Accuracy train: 		 0.7917
# Accuracy test: 			 0.746
# Logloss train: 			 0.434
# Logloss test: 			 0.5039
# Unsure train: 			 4.96%
# Unsure test: 			 7.14%
# 	------------------------------
# 	 l2w_delta
# 	------------------------------
# /home/lucabasa/Git/kaggle_competitions/marc_madness/ncaa/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# /home/lucabasa/Git/kaggle_competitions/marc_madness/ncaa/lib/python3.6/site-packages/xgboost/core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \
# MAE train: 			 14.6129
# MAE test: 			 16.6685
# RMSE train: 			 18.1975
# RMSE test: 			 21.386
# Accuracy train: 		 0.6716
# Accuracy test: 			 0.6111
# Logloss train: 			 0.6203
# Logloss test: 			 0.6616
# Unsure train: 			 7.14%
# Unsure test: 			 11.11%
# 	------------------------------
# 	 tot_delta
# 	------------------------------
# /home/lucabasa/Git/kaggle_competitions/marc_madness/ncaa/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# /home/lucabasa/Git/kaggle_competitions/marc_madness/ncaa/lib/python3.6/site-packages/xgboost/core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \
# MAE train: 			 10.0249
# MAE test: 			 11.3675
# RMSE train: 			 12.4968
# RMSE test: 			 14.0747
# Accuracy train: 		 0.7976
# Accuracy test: 			 0.7421
# Logloss train: 			 0.4334
# Logloss test: 			 0.5042
# Unsure train: 			 4.96%
# Unsure test: 			 5.56%
# 	------------------------------
# ________________________________________

# %%
pipe = Pipeline([('scl', df_p.df_scaler()), ('lasso', Lasso(alpha=0.1))])

fitted, oof_pred, test_pred, imp_coef, train, y_train, test, y_test = random_split(df_train, pipe, kfolds, 'target_points')

rp.report_points(train, test, y_train, y_test, oof_pred, test_pred)
# Out:
# MAE train: 			 9.4494
# MAE test: 			 10.493
# RMSE train: 			 12.02
# RMSE test: 			 13.1618
# Accuracy train: 		 0.8056
# Accuracy test: 			 0.7619
# Logloss train: 			 0.4094
# Logloss test: 			 0.4696
# Unsure train: 			 4.66%
# Unsure test: 			 5.95%
